# %%
import xarray as xr
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Conv3D, Flatten,MaxPooling3D,AveragePooling3D, concatenate,Input ,SpatialDropout3D,Dropout
import keras
from math import e
from keras.models import Model
from sklearn.preprocessing import StandardScaler
from joblib import dump, load
from keras.models import load_model
from sklearn.decomposition import PCA

# %%
# AO Calculations

modelName=['ACCESS-CM2','IITM-ESM','INM-CM5-0']

for m in modelName :

    # Calculate AO - input std normal latitude wighted 1000mb z
    ZData = xr.open_dataset('../../../Data/ssp126/'+m+'/processed/weighted1000Std.nc')
    #SLPData = xr.open_dataset('../eraDown/ERA5_2degree_Down/DailyMean/weighted1000.nc')

    ZData.zg.values
    ZData.zg.values=xr.where(np.isnan(ZData.zg.values),  0.000000000001,ZData.zg.values)
    ZData.zg.values
    print(ZData.zg)
    t1=ZData.zg.stack(z=("lat", "longitude"))
    # fit scaler on training data
    zg_PC =PCA().fit_transform(t1)

    print(zg_PC[:,0].shape)
    AO_ds = xr.Dataset({'AO': (('time'), zg_PC[:,0])}, coords={'time': ZData.time})


    norm = StandardScaler().fit(zg_PC[:,0].reshape(-1, 1))
    # transform training data
    aoX = norm.transform(zg_PC[:,0].reshape(-1, 1))
    aoX.shape

    AO_ds = xr.Dataset({'AO': (('time'), aoX[:,0]*-1.0)}, coords={'time': ZData.time})

    AO_ds.to_netcdf(m+'-AOindex-NDJF-Daily-2015-2100.nc')
    AO_ds.AO.where(AO_ds.AO==AO_ds.AO.max(), drop=True).squeeze()

    AO_ds.AO.where(AO_ds.AO==AO_ds.AO.min(), drop=True).squeeze()
# Out:
# <xarray.DataArray 'zg' (time: 10341, lat: 36, longitude: 180)>
# array([[[ 9.99999996e-13,  9.99999996e-13,  9.99999996e-13, ...,
#           9.99999996e-13,  9.99999996e-13,  9.99999996e-13],
#         [ 9.99999996e-13,  9.99999996e-13,  9.99999996e-13, ...,
#           9.99999996e-13,  9.99999996e-13,  9.99999996e-13],
#         [ 9.99999996e-13,  9.99999996e-13,  9.99999996e-13, ...,
#           9.99999996e-13,  9.99999996e-13,  9.99999996e-13],
#         ...,
#         [ 1.67210653e-01,  1.66339904e-01,  1.65806308e-01, ...,
#           1.71909392e-01,  1.69889256e-01,  1.68487236e-01],
#         [ 1.44768268e-01,  1.44437969e-01,  1.44151971e-01, ...,
#           1.45918012e-01,  1.45414084e-01,  1.45071551e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 9.99999996e-13,  9.99999996e-13,  9.99999996e-13, ...,
#           9.99999996e-13,  9.99999996e-13,  9.99999996e-13],
#         [ 9.99999996e-13,  9.99999996e-13,  9.99999996e-13, ...,
#           9.99999996e-13,  9.99999996e-13,  9.99999996e-13],
#         [ 9.99999996e-13,  9.99999996e-13,  9.99999996e-13, ...,
#           9.99999996e-13,  9.99999996e-13,  9.99999996e-13],
# ...
#           4.26654704e-02,  3.57078239e-02,  2.87792962e-02],
#         [ 1.13572262e-03, -1.55590742e-03, -4.22016950e-03, ...,
#           9.10097454e-03,  6.31372863e-03,  3.71969817e-03],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 9.99999996e-13,  9.99999996e-13,  9.99999996e-13, ...,
#           9.99999996e-13,  9.99999996e-13,  9.99999996e-13],
#         [ 9.99999996e-13,  9.99999996e-13,  9.99999996e-13, ...,
#           9.99999996e-13,  9.99999996e-13,  9.99999996e-13],
#         [ 9.99999996e-13,  9.99999996e-13,  9.99999996e-13, ...,
#           9.99999996e-13,  9.99999996e-13,  9.99999996e-13],
#         ...,
#         [-8.72797519e-02, -9.31329280e-02, -9.90073010e-02, ...,
#          -7.20455572e-02, -7.68763274e-02, -8.16825554e-02],
#         [-7.11648390e-02, -7.32566193e-02, -7.53431395e-02, ...,
#          -6.49438798e-02, -6.72036558e-02, -6.92089647e-02],
#         [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00, ...,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00]]],
#       dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 2015-01-01T12:00:00 ... 2100-12-31T12:00:00
#   * lat        (lat) float32 20.0 22.0 24.0 26.0 28.0 ... 84.0 86.0 88.0 90.0
#   * longitude  (longitude) float32 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
# Attributes:
#     standardize_op_ncl:  dim_standardize_n over dimension(s): time
#     plev:                100000.00000001001
#     standard_name:       geopotential_height
#     long_name:           Geopotential Height (sqrt cosine weighted)
#     units:               m
#     comment:             Geopotential is the sum of the specific gravitationa...
#     cell_methods:        time: mean
#     cell_measures:       area: areacella
#     history:             2019-11-08T11:15:19Z altered by CMOR: replaced missi...
# (10341,)
# <xarray.DataArray 'zg' (time: 10221, lat: 36, longitude: 180)>
# array([[[ 0.20172203,  0.40590218,  0.48100185, ..., -0.44905016,
#          -0.29875773, -0.06138445],
#         [-0.16007325,  0.07122134,  0.23627606, ..., -0.4473838 ,
#          -0.44265616, -0.34865037],
#         [-0.46556672, -0.2785835 , -0.09303068, ..., -0.44643888,
#          -0.5135777 , -0.5449714 ],
#         ...,
#         [-0.22213055, -0.23223734, -0.2422145 , ..., -0.19638245,
#          -0.20508978, -0.21367525],
#         [-0.2138799 , -0.21580394, -0.21770091, ..., -0.2081651 ,
#          -0.21009189, -0.21199709],
#         [-0.        , -0.        , -0.        , ..., -0.        ,
#          -0.        , -0.        ]],
#
#        [[-0.28974783, -0.11636815,  0.00117723, ..., -0.4998342 ,
#          -0.47522107, -0.41670185],
#         [-0.4868395 , -0.42239347, -0.34160495, ..., -0.41405421,
#          -0.45443955, -0.49850023],
#         [-0.618364  , -0.62302816, -0.6005155 , ..., -0.4645394 ,
#          -0.5158582 , -0.5801072 ],
# ...
#         [-0.31968036, -0.30852205, -0.29721478, ..., -0.34059548,
#          -0.3337709 , -0.32679573],
#         [-0.20794298, -0.2043933 , -0.20082614, ..., -0.21554133,
#          -0.21302745, -0.2104943 ],
#         [-0.        , -0.        , -0.        , ..., -0.        ,
#          -0.        , -0.        ]],
#
#        [[ 0.0385656 ,  0.50920296,  0.80287445, ..., -0.2828983 ,
#          -0.44042394, -0.35656887],
#         [ 0.08502911,  0.516691  ,  0.8128401 , ..., -0.01986881,
#          -0.24165149, -0.23598514],
#         [ 0.22993249,  0.467116  ,  0.661097  , ...,  0.33769336,
#           0.17398398,  0.09899359],
#         ...,
#         [-0.21952787, -0.21651106, -0.21335426, ..., -0.21049955,
#          -0.21357127, -0.21658187],
#         [-0.15595384, -0.15514363, -0.15431136, ..., -0.15538241,
#          -0.15558128, -0.15577175],
#         [-0.        , -0.        , -0.        , ..., -0.        ,
#          -0.        , -0.        ]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 2015-01-02T12:00:00 ... 2100-01-01T12:00:00
#   * lat        (lat) float32 20.0 22.0 24.0 26.0 28.0 ... 84.0 86.0 88.0 90.0
#   * longitude  (longitude) float32 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
# Attributes:
#     standardize_op_ncl:  dim_standardize_n over dimension(s): time
#     plev:                100000.0
#     standard_name:       geopotential_height
#     long_name:           Geopotential Height (sqrt cosine weighted)
#     units:               m
#     comment:             Geopotential is the sum of the specific gravitationa...
#     cell_methods:        time: mean
#     cell_measures:       area: areacella
#     history:             2020-10-24T12:17:13Z altered by CMOR: Inverted axis:...
# (10221,)
# <xarray.DataArray 'zg' (time: 10320, lat: 36, longitude: 180)>
# array([[[-0.3112022 ,  0.1712266 ,  0.48020226, ..., -0.6291048 ,
#          -0.82946384, -0.7138282 ],
#         [-0.72950006, -0.25643083,  0.16720264, ..., -0.38877738,
#          -0.8175465 , -0.9636511 ],
#         [-0.9733894 , -0.6839502 , -0.40712535, ..., -0.27707243,
#          -0.77127707, -1.0490981 ],
#         ...,
#         [ 0.3902528 ,  0.38756466,  0.38510555, ...,  0.39989883,
#           0.39639038,  0.39318556],
#         [ 0.3475822 ,  0.346787  ,  0.34602308, ...,  0.3501342 ,
#           0.3492589 ,  0.3484073 ],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ]],
#
#        [[-0.27702466, -0.69659376, -0.69922346, ...,  1.4445982 ,
#           0.9750209 ,  0.36385444],
#         [-0.19242539, -0.73079383, -0.92221844, ...,  1.3101177 ,
#           0.9632928 ,  0.4466785 ],
#         [-0.29594612, -0.90377784, -1.3634291 , ...,  0.9728327 ,
#           0.6857822 ,  0.26372382],
# ...
#         [-0.22413899, -0.22249879, -0.22097667, ..., -0.22983487,
#          -0.22780593, -0.22590728],
#         [-0.2078513 , -0.20758879, -0.20733364, ..., -0.20867454,
#          -0.20839472, -0.20812096],
#         [-0.        , -0.        , -0.        , ..., -0.        ,
#          -0.        , -0.        ]],
#
#        [[ 0.85747653,  0.5066047 ,  0.26220873, ...,  1.5322233 ,
#           1.3346262 ,  1.1201814 ],
#         [ 0.681334  ,  0.36728466,  0.17916018, ...,  1.3546284 ,
#           1.1515572 ,  0.93268615],
#         [ 0.5007677 ,  0.22037448, -0.05197171, ...,  1.1076864 ,
#           0.93006516,  0.7254616 ],
#         ...,
#         [-0.21430105, -0.21008721, -0.20631112, ..., -0.2298644 ,
#          -0.22418192, -0.21899271],
#         [-0.18333144, -0.18247251, -0.18165624, ..., -0.18614952,
#          -0.18517329, -0.18423402],
#         [-0.        , -0.        , -0.        , ..., -0.        ,
#          -0.        , -0.        ]]], dtype=float32)
# Coordinates:
#   * time       (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#   * lat        (lat) float32 20.0 22.0 24.0 26.0 28.0 ... 84.0 86.0 88.0 90.0
#   * longitude  (longitude) float32 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
# Attributes:
#     standardize_op_ncl:  dim_standardize_n over dimension(s): time
#     plev:                100000.0
#     standard_name:       geopotential_height
#     long_name:           Geopotential Height (sqrt cosine weighted)
#     units:               m
#     comment:             Geopotential is the sum of the specific gravitationa...
#     original_name:       zg
#     cell_methods:        time: mean (interval: 1 day)
#     cell_measures:       area: areacella
# (10320,)

# %%
# AO Calculations

modelName=['CanESM5','INM-CM4-8','IPSL-CM6A-LR','MIROC6','MRI-ESM2-0','MPI-ESM1-2-LR','MPI-ESM1-2-HR','EC-Earth3']

for m in modelName :

    # Calculate AO - input std normal latitude wighted 1000mb z
    ZData = xr.open_dataset('../../../Data/ssp126/'+m+'/processed/weighted1000Std.nc')
    #SLPData = xr.open_dataset('../eraDown/ERA5_2degree_Down/DailyMean/weighted1000.nc')

    ZData.zg.values
    ZData.zg.values=xr.where(np.isnan(ZData.zg.values),  0.000000000001,ZData.zg.values)
    ZData.zg.values

    t1=ZData.zg.stack(z=("lat", "lon"))
    # fit scaler on training data
    zg_PC =PCA().fit_transform(t1)

    print(zg_PC[:,0].shape)
    AO_ds = xr.Dataset({'AO': (('time'), zg_PC[:,0])}, coords={'time': ZData.time})


    norm = StandardScaler().fit(zg_PC[:,0].reshape(-1, 1))
    # transform training data
    aoX = norm.transform(zg_PC[:,0].reshape(-1, 1))
    aoX.shape

    AO_ds = xr.Dataset({'AO': (('time'), aoX[:,0]*-1.0)}, coords={'time': ZData.time})

    AO_ds.to_netcdf(m+'-AOindex-NDJF-Daily-2015-2100.nc')
    AO_ds.AO.where(AO_ds.AO==AO_ds.AO.max(), drop=True).squeeze()

    AO_ds.AO.where(AO_ds.AO==AO_ds.AO.min(), drop=True).squeeze()
# Out:
# (10320,)
# (10320,)
# (10341,)
# (10341,)
# (10341,)
# (10341,)
# (10341,)
# (10341,)
