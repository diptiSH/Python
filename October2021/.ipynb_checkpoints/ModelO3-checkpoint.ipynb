# %%
import xarray as xr
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from math import e
from joblib import dump, load
import statistics as st
from calendar import isleap

# %%
# Read Orography
OroData = xr.open_dataset('../../Data/eraDown/ERA5_2degree_Down/DailyMean/ERA5IGP_Orography.nc')
OroD = OroData.sel(latitude=slice(32,24),longitude=slice(74,86))
# create mask
oro = OroD.z
oro.values = OroD.z.values/9.81
oro.attrs
oro.attrs['units']='meter'
oro.attrs['long_name']='Orography'
oro.values[oro.values>500.1]=np.NaN
mask=oro.values/oro.values

# %% [markdown]
# AODHistvals=[]
# # AOD Data
# AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-201412.nc')
# AODDataIPSL.od550aer.time[0]
# histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
# #histAOD[0].values
# histAODIPSL.values=histAODIPSL.values-histAODIPSL[0].values
# histAODIPSL[1].values
# histAODIPSL.values=histAODIPSL.values*mask
#
# # Area Average
# aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)
#
# aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
# AODHistvals.append(aodTs)
#
# # AOD Data
# AODDataACCESS = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc')
# AODDataACCESS.od550aer.time[0]
# histAOD=AODDataACCESS.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
# histAOD[0].values
# histAOD.values=histAOD.values-histAOD[0].values
# histAOD[1].values
# histAOD.values=histAOD.values*mask
#
# # Area Average
# aodTS1=histAOD.mean(dim=['latitude','longitude'], skipna=True)
#
# aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
# AODHistvals.append(aodTs)
#
# plt.plot(AODHistvals[0],label='IPSL')
# plt.plot(AODHistvals[1],label='ACCESS')
# plt.legend()

# %% [markdown]
# AODHistvals=[]
# # AOD Data
# AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-201412.nc')
# AODDataIPSL.od550aer.time[0]
# histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
# #histAOD[0].values
# histAODIPSL[1].values
# histAODIPSL.values=histAODIPSL.values*mask
#
# # Area Average
# aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)
#
# aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
# x=np.arange(1981,2014)
# histAODTs=[]
# for yr in x :
#     InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
#     EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
#    # print(EnDString)
#     aodT=aodTs.sel(time=slice(InDString,EnDString))
#    # print(rhT.time)
#     histAODTs.append(aodT.mean())
# AODHistvals.append(histAODTs)
#
# # AOD Data
# AODDataACCESS = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc')
# AODDataACCESS.od550aer.time[0]
# histAOD=AODDataACCESS.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
#
# #histAOD.values=histAOD.values-histAOD[0].values
# histAOD[1].values
# histAOD.values=histAOD.values*mask
#
#
# # Area Average
# aodTS1=histAOD.mean(dim=['latitude','longitude'], skipna=True)
#
# aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
# histAODTs=[]
# for yr in x :
#     InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
#     EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
#    # print(EnDString)
#     aodT=aodTs.sel(time=slice(InDString,EnDString))
#    # print(rhT.time)
#     histAODTs.append(aodT.mean())
# AODHistvals.append(histAODTs)
#
#
# AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHanthrop_iitmesm_1850_2015_historig_AOD550nm.nc')
# #AODDataIPSL.od550aer.time[0]
# histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).aod_band10
# #histAOD[0].values
# histAODIPSL[1].values
# histAODIPSL.values=histAODIPSL.values*mask
#
# t1=pd.to_datetime(histAODIPSL.time, format='%Y%m%d')
#
# histAODIPSL['time']=t1
# #histAODIPSL.assign_coords(time=t1)
#
# # Area Average
# aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)
#
# aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
# histAODTs=[]
# for yr in x :
#     InDString=np.datetime64(str(yr-1)+'-12-01T00:00:00')
#     EnDString=np.datetime64(str(yr)+'-01-31T00:00:00')
#    # print(EnDString)
#     aodT=aodTs.sel(time=slice(InDString,EnDString))
#    # print(rhT.time)
#     histAODTs.append(aodT.mean())
# AODHistvals.append(histAODTs)
#
#
#
#
#
# fig = plt.figure(figsize=(10,7))
# plt.plot(x,AODHistvals[0],label='IPSL')
# plt.plot(x,AODHistvals[1],label='ACCESS')
# plt.plot(x,AODHistvals[2],label='EC-Earth3')
# plt.legend()
#
# #plt.savefig('HistAOD.eps')
# plt.show()

# %%
AODHistvals=[]
# AOD Data
AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/AnthroRegridNHod550aer_AERmon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc')
AODDataIPSL.od550aer.time[0]
histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
#histAOD[0].values
histAODIPSL[1].values
histAODIPSL.values=histAODIPSL.values*mask

# Area Average
aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
x=np.arange(1981,2014)
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs) 

# AOD Data
AODDataACCESS = xr.open_dataset('../../Data/CMIP6AerosolData/AnthroRegridNHod550aer_AERmon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-201412.nc')
AODDataACCESS.od550aer.time[0]
histAOD=AODDataACCESS.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer

#histAOD.values=histAOD.values-histAOD[0].values
histAOD[1].values
histAOD.values=histAOD.values*mask


# Area Average
aodTS1=histAOD.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs)


AODDataESM = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHanthrop_iitmesm_1850_2015_historig_AOD550nm.nc')
#AODDataIPSL.od550aer.time[0]
AODDataESM=AODDataESM.sel(latitude=slice(32,24),longitude=slice(74,86)).aod_band10
#histAOD[0].values
AODDataESM[1].values
AODDataESM.values=AODDataESM.values*mask

t1=pd.to_datetime(AODDataESM.time, format='%Y%m%d')

AODDataESM['time']=t1
#histAODIPSL.assign_coords(time=t1)

# Area Average
aodTS1=AODDataESM.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T00:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T00:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs)


   


fig = plt.figure(figsize=(10,7))
plt.plot(x,AODHistvals[0],label='IPSL',color='Red')
plt.plot(x,AODHistvals[1],label='ACCESS',color='Blue')
plt.plot(x,AODHistvals[2],label='EC-Earth3',color='Black')
plt.legend()

plt.savefig('HistAOD_Anthropogenic.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
AODHistvals=[]
# AOD Data
AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/AnthroRegridNHod550aer_AERmon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc')
AODDataIPSL.od550aer.time[0]
histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
#histAOD[0].values
histAODIPSL[1].values
histAODIPSL.values=histAODIPSL.values*mask

# Area Average
aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
x=np.arange(1981,2014)
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs) 

# AOD Data
AODDataACCESS = xr.open_dataset('../../Data/CMIP6AerosolData/AnthroRegridNHod550aer_AERmon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-201412.nc')
AODDataACCESS.od550aer.time[0]
histAOD=AODDataACCESS.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer

#histAOD.values=histAOD.values-histAOD[0].values
histAOD[1].values
histAOD.values=histAOD.values*mask


# Area Average
aodTS1=histAOD.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs)



histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T00:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T00:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs)

  


fig = plt.figure(figsize=(10,7))
plt.plot(x,AODHistvals[0],label='IPSL',color='Red')
plt.plot(x,AODHistvals[1],label='ACCESS',color='Blue')
plt.legend()

plt.savefig('HistAOD_Anthropogenic.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
AODHistvals=[]
# AOD Data
AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc')
AODDataIPSL.od550aer.time[0]
histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
#histAOD[0].values
histAODIPSL[1].values
histAODIPSL.values=histAODIPSL.values*mask

# Area Average
aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
x=np.arange(1981,2014)
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs) 

# AOD Data
AODDataACCESS = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-201412.nc')
AODDataACCESS.od550aer.time[0]
histAOD=AODDataACCESS.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer

#histAOD.values=histAOD.values-histAOD[0].values
histAOD[1].values
histAOD.values=histAOD.values*mask


# Area Average
aodTS1=histAOD.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs)



histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T00:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T00:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs)

  


fig = plt.figure(figsize=(10,7))
plt.plot(x,AODHistvals[0],label='IPSL',color='Red')
plt.plot(x,AODHistvals[1],label='ACCESS',color='Blue')
plt.legend()

plt.savefig('HistAOD_Anthropogenic.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
ssps=['126','245','370','585']

# %%
fig = plt.figure(figsize=(22.5,5))

i=1
for sp in ssps:
    
    x=np.arange(1981,2014)

    plt.subplot(1, 4, i)

    #plt.plot(x,EnsBCHist,label='Historical',color='gainsboro')
    plt.plot(x,AODHistvals[0],color='lightcoral')
    plt.plot(x,AODHistvals[1],color='cornflowerblue')
    x=np.arange(2016,2101)
    AODFut=[]
# AOD Data
    AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_IPSL-CM6A-LR_ssp'+sp+'_r1i1p1f1_gr_201501-210012.nc')
    AODDataIPSL.od550aer.time[0]
    histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
#histAOD[0].values
    histAODIPSL[1].values
    histAODIPSL.values=histAODIPSL.values*mask

# Area Average
    aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)

    aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('2015-12-1','2100-1-31')))
    #x=np.arange(1981,2014)
    histAODTs=[]
    for yr in x :
        InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
        EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
        aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
        histAODTs.append(aodT.mean())
    AODFut.append(histAODTs) 

    # AOD Data
    AODDataACCESS = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_ACCESS-CM2_ssp'+sp+'_r1i1p1f1_gn_201501-210012.nc')
    AODDataACCESS.od550aer.time[0]
    histAOD=AODDataACCESS.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer

#histAOD.values=histAOD.values-histAOD[0].values
    histAOD[1].values
    histAOD.values=histAOD.values*mask


# Area Average
    aodTS1=histAOD.mean(dim=['latitude','longitude'], skipna=True)

    aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('2015-12-1','2100-1-31')))
    histAODTs=[]
    for yr in x :
        InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
        EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
        aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
        histAODTs.append(aodT.mean())
    AODFut.append(histAODTs)

    histAODTs=[]
    for yr in x :
        InDString=np.datetime64(str(yr-1)+'-12-01T00:00:00')
        EnDString=np.datetime64(str(yr)+'-01-31T00:00:00')
   # print(EnDString)
        aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
        histAODTs.append(aodT.mean())
    AODFut.append(histAODTs)
    plt.plot(x,AODFut[0],color='lightcoral')
    jointList=AODHistvals[0]+AODFut[0]
    S = pd.Series (jointList)
    xTotal=np.arange(1982,2100)
    rENS=S.rolling(10, center=True, min_periods=1).mean()
    plt.plot(xTotal,rENS,label='IPSL-CM6A-LR',color='red')
    plt.plot(x,AODFut[1],color='cornflowerblue')
    jointList=AODHistvals[1]+AODFut[1]
    S = pd.Series (jointList)
    xTotal=np.arange(1982,2100)
    rENS=S.rolling(10, center=True, min_periods=1).mean()
    plt.plot(xTotal,rENS,label='ACCESS-CM2',color='blue')
    plt.ylim(0.1,1.0)
    plt.axvline(x=2014,color='black',linestyle=':')
    plt.xlabel('Year') 
    if i == 1:
        plt.legend()
        plt.ylabel('AOD at 550nm')
    i=i+1

plt.savefig('AOD_ts_panel_10YearMean.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
