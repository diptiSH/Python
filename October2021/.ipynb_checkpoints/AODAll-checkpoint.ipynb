# %%
import xarray as xr
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from math import e
from joblib import dump, load
import statistics as st
from calendar import isleap

# %%
# Read Orography
OroData = xr.open_dataset('../../Data/eraDown/ERA5_2degree_Down/DailyMean/ERA5IGP_Orography.nc')
OroD = OroData.sel(latitude=slice(32,24),longitude=slice(74,86))
# create mask
oro = OroD.z
oro.values = OroD.z.values/9.81
oro.attrs
oro.attrs['units']='meter'
oro.attrs['long_name']='Orography'
oro.values[oro.values>500.1]=np.NaN
mask=oro.values/oro.values

# %% [markdown]
# AODHistvals=[]
# # AOD Data
# AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-201412.nc')
# AODDataIPSL.od550aer.time[0]
# histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
# #histAOD[0].values
# histAODIPSL.values=histAODIPSL.values-histAODIPSL[0].values
# histAODIPSL[1].values
# histAODIPSL.values=histAODIPSL.values*mask
#
# # Area Average
# aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)
#
# aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
# AODHistvals.append(aodTs)
#
# # AOD Data
# AODDataACCESS = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc')
# AODDataACCESS.od550aer.time[0]
# histAOD=AODDataACCESS.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
# histAOD[0].values
# histAOD.values=histAOD.values-histAOD[0].values
# histAOD[1].values
# histAOD.values=histAOD.values*mask
#
# # Area Average
# aodTS1=histAOD.mean(dim=['latitude','longitude'], skipna=True)
#
# aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
# AODHistvals.append(aodTs)
#
# plt.plot(AODHistvals[0],label='IPSL')
# plt.plot(AODHistvals[1],label='ACCESS')
# plt.legend()

# %%
AODHistvals=[]
# AOD Data
AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-201412.nc')
AODDataIPSL.od550aer.time[0]
histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
#histAOD[0].values
histAODIPSL[1].values
histAODIPSL.values=histAODIPSL.values*mask

# Area Average
aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
x=np.arange(1981,2014)
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs) 

# AOD Data
AODDataACCESS = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHod550aer_AERmon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc')
AODDataACCESS.od550aer.time[0]
histAOD=AODDataACCESS.sel(latitude=slice(32,24),longitude=slice(74,86)).od550aer
print(histAOD[0].values)
#histAOD.values=histAOD.values-histAOD[0].values
histAOD[1].values
histAOD.values=histAOD.values*mask
print(histAOD[0].values)

print(histAOD[198].values)

# Area Average
aodTS1=histAOD.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T12:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T12:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs)


AODDataIPSL = xr.open_dataset('../../Data/CMIP6AerosolData/RegridNHDecJan_anthrop_iitmesm_1850_2015_AOD550nm.nc')
#AODDataIPSL.od550aer.time[0]
histAODIPSL=AODDataIPSL.sel(latitude=slice(32,24),longitude=slice(74,86)).aod_band10
#histAOD[0].values
histAODIPSL[1].values
histAODIPSL.values=histAODIPSL.values*mask
print(histAODIPSL.time)
t1=pd.to_datetime(histAODIPSL.time, format='%Y%m%d')
print(t1)
histAODIPSL['time']=t1
#histAODIPSL.assign_coords(time=t1)

print(histAODIPSL.time)

# Area Average
aodTS1=histAODIPSL.mean(dim=['latitude','longitude'], skipna=True)

aodTs=(aodTS1[((aodTS1.time.dt.month>11) | (aodTS1.time.dt.month<2)) ].sel(time=slice('1980-12-1','2014-1-31')))
histAODTs=[]
for yr in x :
    InDString=np.datetime64(str(yr-1)+'-12-01T00:00:00')
    EnDString=np.datetime64(str(yr)+'-01-31T00:00:00')
   # print(EnDString)
    aodT=aodTs.sel(time=slice(InDString,EnDString))
   # print(rhT.time)
    histAODTs.append(aodT.mean())
AODHistvals.append(histAODTs)

print(aodTs.values)

   


fig = plt.figure(figsize=(10,7))
plt.plot(x,AODHistvals[0],label='IPSL')
plt.plot(x,AODHistvals[1],label='ACCESS')
plt.plot(x,AODHistvals[2],label='EC-Earth3')
plt.legend()

plt.savefig('HistAOD.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# [[0.04183005 0.03093125 0.01681199 0.01167599 0.01083008 0.01069928
#   0.01089209]
#  [0.05572459 0.04860834 0.03638541 0.02281945 0.01623684 0.0131143
#   0.01215448]
#  [0.07115288 0.0608706  0.05268242 0.04554735 0.03635243 0.02945011
#   0.02364879]
#  [0.07193132 0.06030118 0.05504467 0.05206133 0.04891291 0.047853
#   0.04716783]
#  [0.06457315 0.05591686 0.05152195 0.04868224 0.04663424 0.04575924
#   0.04662272]]
# [[0.04183005        nan        nan        nan        nan        nan
#          nan]
#  [0.05572459 0.04860834 0.03638541        nan        nan        nan
#          nan]
#  [0.07115288 0.0608706  0.05268242 0.04554735 0.03635243        nan
#          nan]
#  [0.07193132 0.06030118 0.05504467 0.05206133 0.04891291 0.047853
#   0.04716783]
#  [0.06457315 0.05591686 0.05152195 0.04868224 0.04663424 0.04575924
#   0.04662272]]
# [[0.3520868         nan        nan        nan        nan        nan
#          nan]
#  [0.5839973  0.48613945 0.32288766        nan        nan        nan
#          nan]
#  [0.60520345 0.5106896  0.40756342 0.29346994 0.19396868        nan
#          nan]
#  [0.29779387 0.2955994  0.2773863  0.2223658  0.18150301 0.14011623
#   0.10280244]
#  [0.14667091 0.15938571 0.1591428  0.13396521 0.11557243 0.09923302
#   0.08784098]]
# <xarray.DataArray 'time' (time: 334)>
# array([18490101., 18491201., 18500101., ..., 20141201., 20150101., 20151201.])
# Coordinates:
#   * time     (time) float64 1.849e+07 1.849e+07 1.85e+07 ... 2.015e+07 2.015e+07
# Attributes:
#     standard_name:  time
#     long_name:      initial time
#     units:          day as %Y%m%d.%f
#     calendar:       standard
#     axis:           T
# DatetimeIndex(['1849-01-01', '1849-12-01', '1850-01-01', '1850-12-01',
#                '1851-01-01', '1851-12-01', '1852-01-01', '1852-12-01',
#                '1853-01-01', '1853-12-01',
#                ...
#                '2011-01-01', '2011-12-01', '2012-01-01', '2012-12-01',
#                '2013-01-01', '2013-12-01', '2014-01-01', '2014-12-01',
#                '2015-01-01', '2015-12-01'],
#               dtype='datetime64[ns]', length=334, freq=None)
# <xarray.DataArray 'time' (time: 334)>
# array(['1849-01-01T00:00:00.000000000', '1849-12-01T00:00:00.000000000',
#        '1850-01-01T00:00:00.000000000', ..., '2014-12-01T00:00:00.000000000',
#        '2015-01-01T00:00:00.000000000', '2015-12-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1849-01-01 1849-12-01 ... 2015-12-01
# [0.098052   0.09967434 0.10095449 0.10253479 0.10385698 0.10539524
#  0.10675947 0.10825565 0.10966196 0.1111161  0.11256445 0.11397654
#  0.11546694 0.11683699 0.11836942 0.11969741 0.12127192 0.12255785
#  0.12417442 0.12507401 0.12672961 0.12759016 0.1292848  0.13010633
#  0.13184002 0.13262248 0.13439521 0.13513862 0.13695039 0.13765477
#  0.13950561 0.14017092 0.1420608  0.14268708 0.14461601 0.14520322
#  0.14717121 0.14771937 0.1497264  0.15218815 0.15425788 0.15665694
#  0.15878935 0.16112572 0.16332082 0.16559449 0.1678523  0.17006327
#  0.17238377 0.         0.         0.00142218 0.00151273 0.00146668
#  0.0015585  0.00151119 0.00160427 0.00155569 0.00165004 0.0016002
#  0.00169581 0.00163596 0.00173252 0.00167172 0.00176924 0.00170748
#  0.00180595 0.00174325]

# %%
t1=histAODIPSL.sel(time=slice('2006-12-1','2007-1-31'))
print(t1)
histAODIPSL.longitude
# Out:
# <xarray.DataArray 'aod_band10' (time: 2, latitude: 5, longitude: 7)>
# array([[[0.00054966,        nan,        nan,        nan,        nan,
#                 nan,        nan],
#         [0.0008191 , 0.00077   , 0.00072596,        nan,        nan,
#                 nan,        nan],
#         [0.00120197, 0.00113599, 0.00107727, 0.00102762, 0.00098908,
#                 nan,        nan],
#         [0.00173668, 0.00165065, 0.00157515, 0.00151283, 0.0014665 ,
#          0.00143904, 0.0014334 ],
#         [0.0024702 , 0.00236148, 0.00226811, 0.00219403, 0.00214316,
#          0.00211924, 0.00212566]],
#
#        [[0.00055571,        nan,        nan,        nan,        nan,
#                 nan,        nan],
#         [0.00082672, 0.0007731 , 0.00072327,        nan,        nan,
#                 nan,        nan],
#         [0.00121071, 0.00113711, 0.00106857, 0.00100638, 0.00095205,
#                 nan,        nan],
#         [0.0017454 , 0.00164667, 0.00155469, 0.0014713 , 0.00139856,
#          0.00133865, 0.00129397],
#         [0.00247683, 0.00234747, 0.00222709, 0.00211835, 0.00202404,
#          0.001947  , 0.00189008]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 2006-12-01 2007-01-01
#   * longitude  (longitude) float32 74.0 76.0 78.0 80.0 82.0 84.0 86.0
#   * latitude   (latitude) float32 32.0 30.0 28.0 26.0 24.0
# Attributes:
#     long_name:  aerosol optical depth
# <xarray.DataArray 'longitude' (longitude: 7)>
# array([74., 76., 78., 80., 82., 84., 86.], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 74.0 76.0 78.0 80.0 82.0 84.0 86.0
# Attributes:
#     standard_name:  longitude
#     long_name:      longitude
#     units:          degrees_east
#     axis:           X

# %%
t1=histAODIPSL.sel(time=slice('2000-12-1','2001-1-31'))
print(t1)
# Out:
# <xarray.DataArray 'aod_band10' (time: 2, latitude: 5, longitude: 7)>
# array([[[0.09423912,        nan,        nan,        nan,        nan,
#                 nan,        nan],
#         [0.12225825, 0.11943001, 0.09974627,        nan,        nan,
#                 nan,        nan],
#         [0.1331778 , 0.14218922, 0.1506111 , 0.14807007, 0.1283317 ,
#                 nan,        nan],
#         [0.14025258, 0.14993426, 0.16442944, 0.17787936, 0.1861811 ,
#          0.19020122, 0.17995211],
#         [0.1478819 , 0.15448534, 0.16381125, 0.1735926 , 0.18349956,
#          0.19081968, 0.2069574 ]],
#
#        [[0.09582471,        nan,        nan,        nan,        nan,
#                 nan,        nan],
#         [0.12421762, 0.12138935, 0.10145849,        nan,        nan,
#                 nan,        nan],
#         [0.13528742, 0.14446503, 0.15303859, 0.1494077 , 0.13009025,
#                 nan,        nan],
#         [0.1424642 , 0.15232567, 0.16705452, 0.1800402 , 0.18892422,
#          0.193347  , 0.18303427],
#         [0.15018949, 0.15693748, 0.16643417, 0.17633714, 0.18646443,
#          0.19396955, 0.21040808]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-12-01 2001-01-01
#   * longitude  (longitude) float32 74.0 76.0 78.0 80.0 82.0 84.0 86.0
#   * latitude   (latitude) float32 32.0 30.0 28.0 26.0 24.0
# Attributes:
#     long_name:  aerosol optical depth
