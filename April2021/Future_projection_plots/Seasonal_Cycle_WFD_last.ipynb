# %%
import xarray as xr
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from joblib import dump, load
import statistics as st

# %%
y   = load('../../March2021/Observation_models/ObsY.joblib')
CNN = load('../../March2021/Observation_models/CNNY.joblib')
histEns = load ('WFD_historical_ensembleMean_Best5.joblib')

# %%
def getSeasonalCycle( dArray ):
   #"This function gives TS of categories of each type for each season e.g. if year
   #  is 1981 then it will contain values between 1dec1980 to 31jan1981"
    fg=dArray.groupby('time.dayofyear').mean()
    
    
    
    return fg

# %%
#'ACCESS-CM2','IITM-ESM', 'IPSL-CM6A-LR', 
#          'MPI-ESM1-2-LR','EC-earth3'

# %% [markdown]
# ACCESS_CM2_ssp126=load('../../April2021/New_ssp126/Modelplots_future/ACCESS-CM2_ssp126.joblib')
# ACCESS_CM2_ssp370=load('../../April2021/New_ssp370/Modelplots_future/ACCESS-CM2_ssp370.joblib')
# ACCESS_CM2_ssp585=load('../../April2021/New_ssp585/Modelplots_future/ACCESS-CM2_ssp585.joblib')
# IITM_ESM_ssp126=load('../../April2021/New_ssp126/Modelplots_future/IITM-ESM_ssp126.joblib')
# IITM_ESM_ssp370=load('../../April2021/New_ssp370/Modelplots_future/IITM-ESM_ssp370.joblib')
# IITM_ESM_ssp585=load('../../April2021/New_ssp585/Modelplots_future/IITM-ESM_ssp585.joblib')
# IPSL_CM6A_LR_ssp126=load('../../April2021/New_ssp126/Modelplots_future/IPSL-CM6A-LR_ssp126.joblib')
# IPSL_CM6A_LR_ssp370=load('../../April2021/New_ssp370/Modelplots_future/IPSL-CM6A-LR_ssp370.joblib')
# IPSL_CM6A_LR_ssp585=load('../../April2021/New_ssp585/Modelplots_future/IPSL-CM6A-LR_ssp585.joblib')
# MPI_ESM1_2_LR_ssp126=load('../../April2021/New_ssp126/Modelplots_future/MPI-ESM1-2-LR_ssp126.joblib')
# MPI_ESM1_2_LR_ssp370=load('../../April2021/New_ssp370/Modelplots_future/MPI-ESM1-2-LR_ssp370.joblib')
# MPI_ESM1_2_LR_ssp585=load('../../April2021/New_ssp585/Modelplots_future/MPI-ESM1-2-LR_ssp585.joblib')
# EC_Earth3_ssp126=load('../../April2021/New_ssp126/Modelplots_future/EC-Earth3_ssp126.joblib')
# EC_Earth3_ssp370=load('../../April2021/New_ssp370/Modelplots_future/EC-Earth3_ssp370.joblib')
# EC_Earth3_ssp585=load('../../April2021/New_ssp585/Modelplots_future/EC-Earth3_ssp585.joblib')

# %% [markdown]
# ACCESS_CM2_ssp126_first=ACCESS_CM2_ssp126.sel(time=slice('2015-1-1','2065-12-31'))
# ACCESS_CM2_ssp126_second=ACCESS_CM2_ssp126.sel(time=slice('2066-1-1','2100-12-31'))
# ACCESS_CM2_ssp370_first=ACCESS_CM2_ssp370.sel(time=slice('2015-1-1','2065-12-31'))
# ACCESS_CM2_ssp370_second=ACCESS_CM2_ssp370.sel(time=slice('2066-1-1','2100-12-31'))
# ACCESS_CM2_ssp585_first=ACCESS_CM2_ssp585.sel(time=slice('2015-1-1','2065-12-31'))
# ACCESS_CM2_ssp585_second=ACCESS_CM2_ssp585.sel(time=slice('2066-1-1','2100-12-31'))
# MPI_ESM1_2_LR_ssp126_first=MPI_ESM1_2_LR_ssp126.sel(time=slice('2015-1-1','2065-12-31'))
# MPI_ESM1_2_LR_ssp126_second=MPI_ESM1_2_LR_ssp126.sel(time=slice('2066-1-1','2100-12-31'))
# MPI_ESM1_2_LR_ssp370_first=MPI_ESM1_2_LR_ssp370.sel(time=slice('2015-1-1','2065-12-31'))
# MPI_ESM1_2_LR_ssp370_second=MPI_ESM1_2_LR_ssp370.sel(time=slice('2066-1-1','2100-12-31'))
# MPI_ESM1_2_LR_ssp585_first=MPI_ESM1_2_LR_ssp585.sel(time=slice('2015-1-1','2065-12-31'))
# MPI_ESM1_2_LR_ssp585_second=MPI_ESM1_2_LR_ssp585.sel(time=slice('2066-1-1','2100-12-31'))
# IPSL_CM6A_LR_ssp126_first=IPSL_CM6A_LR_ssp126.sel(time=slice('2015-1-1','2065-12-31'))
# IPSL_CM6A_LR_ssp126_second=IPSL_CM6A_LR_ssp126.sel(time=slice('2066-1-1','2100-12-31'))
# IPSL_CM6A_LR_ssp370_first=IPSL_CM6A_LR_ssp370.sel(time=slice('2015-1-1','2065-12-31'))
# IPSL_CM6A_LR_ssp370_second=IPSL_CM6A_LR_ssp370.sel(time=slice('2066-1-1','2100-12-31'))
# IPSL_CM6A_LR_ssp585_first=IPSL_CM6A_LR_ssp585.sel(time=slice('2015-1-1','2065-12-31'))
# IPSL_CM6A_LR_ssp585_second=IPSL_CM6A_LR_ssp585.sel(time=slice('2066-1-1','2100-12-31'))
# IITM_ESM_ssp126_first=IITM_ESM_ssp126.sel(time=slice('2015-1-1','2065-12-31'))
# IITM_ESM_ssp126_second=IITM_ESM_ssp126.sel(time=slice('2066-1-1','2100-12-31'))
# IITM_ESM_ssp370_first=IITM_ESM_ssp370.sel(time=slice('2015-1-1','2065-12-31'))
# IITM_ESM_ssp370_second=IITM_ESM_ssp370.sel(time=slice('2066-1-1','2100-12-31'))
# IITM_ESM_ssp585_first=IITM_ESM_ssp585.sel(time=slice('2015-1-1','2065-12-31'))
# IITM_ESM_ssp585_second=IITM_ESM_ssp585.sel(time=slice('2066-1-1','2100-12-31'))
# EC_Earth3_ssp126_first=EC_Earth3_ssp126.sel(time=slice('2015-1-1','2065-12-31'))
# EC_Earth3_ssp126_second=EC_Earth3_ssp126.sel(time=slice('2066-1-1','2100-12-31'))
# EC_Earth3_ssp370_first=EC_Earth3_ssp370.sel(time=slice('2015-1-1','2065-12-31'))
# EC_Earth3_ssp370_second=EC_Earth3_ssp370.sel(time=slice('2066-1-1','2100-12-31'))
# EC_Earth3_ssp585_first=EC_Earth3_ssp585.sel(time=slice('2015-1-1','2065-12-31'))
# EC_Earth3_ssp585_second=EC_Earth3_ssp585.sel(time=slice('2066-1-1','2100-12-31'))

# %% [markdown]
# #fig = plt.figure(figsize=(20,10))
# fig = plt.figure(figsize=(10,6))
# x=np.arange(1,63)
# #fMean=list()
# fCC=list()
# OTs1=getSeasonalCycle(y)
# OTs2=OTs1.roll(dayofyear=31)
# OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
# classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
# class_colours = ['red','chocolate','lime','plum','grey']
#
# # Obs
# ts1=getSeasonalCycle(y)
#
# ts2=ts1.roll(dayofyear=31)
# ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
#     #print(xr.corr(ts, OTs))
#
#     #fMean.append((ts))
# plt.plot(x,ts,label='obs', color='black')
#
# for ( cL, cO) in zip(classes,class_colours):
#     fL=load('../../April2021/New_ssp126/Modelplots_future/'+cL+'_ssp126.joblib')
#     fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
#     ts1=getSeasonalCycle(fL1)
#     print(cL)
#     ts2=ts1.roll(dayofyear=31)
#     ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
#     #print(xr.corr(ts, OTs))
#     fCC.append(xr.corr(ts, OTs))
#     #fMean.append((ts))
#     plt.plot(x,ts,label=cL, color=cO,  linestyle='-')
#     fL=load('../../April2021/New_ssp370/Modelplots_future/'+cL+'_ssp370.joblib')
#     fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
#     ts1=getSeasonalCycle(fL1)
#     print(cL)
#     ts2=ts1.roll(dayofyear=31)
#     ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
#     #print(xr.corr(ts, OTs))
#     fCC.append(xr.corr(ts, OTs))
#     #fMean.append((ts))
#     plt.plot(x,ts,label=cL, color=cO,  linestyle='-.')
#     fL=load('../../April2021/New_ssp585/Modelplots_future/'+cL+'_ssp585.joblib')
#     fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
#     ts1=getSeasonalCycle(fL1)
#     print(cL)
#     ts2=ts1.roll(dayofyear=31)
#     ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
#     #print(xr.corr(ts, OTs))
#     fCC.append(xr.corr(ts, OTs))
#     #fMean.append((ts))
#     plt.plot(x,ts,label=cL, color=cO,  linestyle='--')
#
# plt.xlabel('Day of season')
# plt.ylabel('Probability of being widespread fog day')
# #plt.legend()
# print(fCC)
# plt.savefig('FogFraction_SC.eps')
# #plt.savefig('FogFraction_SC_legend.eps')
# plt.show()
# ##plt.legend()

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
y.values=y.where(y>=0.46,0)
y.values=y.where(y==0.0,1)
CNN.values=CNN.where(CNN>=0.46,0)
CNN.values=CNN.where(CNN==0.0,1)


OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]


CNNTs1=getSeasonalCycle(CNN)
CNNTs2=CNNTs1.roll(dayofyear=31)
CNNTs=CNNTs2[(CNNTs2.dayofyear<366) | (CNNTs2.dayofyear>366)]
CNNTs

MTs=[]

classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']


for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp126/Modelplots_future/'+cL+'_ssp126.joblib')
    fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
    fL1.values=fL1.where(fL1>=0.46,0)
    fL1.values=fL1.where(fL1==0.0,1)
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))
    MTs.append(ts)
MS=np.array(MTs)
print(np.mean(MS[:,61]))

meanMS=np.mean(MS, axis=0)
minMS=np.amin(MS,axis=0)
maxMS=np.amax(MS,axis=0)

plt.plot(x,OTs*100.0,label='Obs', color='black')
plt.plot(x,CNNTs*100.0,label='CNN', color='orange')

plt.fill_between(x, maxMS*100.0,minMS*100.0,
                 color="skyblue", alpha=0.4,label='Spread of the models')
#plt.fill_between(x, minMS,
#                 color="white", alpha=0.4)

plt.plot(x,meanMS*100.0,label='Near-Future Ensemble Mean', color='red')
plt.plot(x,histEns*100.0,label='Historical Ensemble Mean', color='blue')

plt.ylim([0, 70])
plt.ylabel('Widespread Fog Occurances')  
plt.xlabel('Day of season')
    
plt.legend()    
plt.savefig('WFD_SC_126_2015-2065.eps')
#plt.savefig('FogFraction_SC_legend.eps')
plt.show()
##plt.legend() 

##print('\n'.join(map(str, meanMS*100.0)))
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ACCESS-CM2
# IITM-ESM
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# EC-Earth3
# 0.06842105

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
y.values=y.where(y>=0.46,0)
y.values=y.where(y==0.0,1)
CNN.values=CNN.where(CNN>=0.46,0)
CNN.values=CNN.where(CNN==0.0,1)

OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]


CNNTs1=getSeasonalCycle(CNN)
CNNTs2=CNNTs1.roll(dayofyear=31)
CNNTs=CNNTs2[(CNNTs2.dayofyear<366) | (CNNTs2.dayofyear>366)]
CNNTs

MTs=[]

classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']


for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp245/Modelplots_future/'+cL+'_ssp245.joblib')
    fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
    fL1.values=fL1.where(fL1>=0.46,0)
    fL1.values=fL1.where(fL1==0.0,1)
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))
    MTs.append(ts)
MS=np.array(MTs)
print(np.mean(MS[:,61]))

meanMS=np.mean(MS, axis=0)
minMS=np.amin(MS,axis=0)
maxMS=np.amax(MS,axis=0)

plt.plot(x,OTs*100.0,label='Obs', color='black')
plt.plot(x,CNNTs*100.0,label='CNN', color='orange')

plt.fill_between(x, maxMS*100.0,minMS*100.0,
                 color="skyblue", alpha=0.4,label='Spread of the models')
#plt.fill_between(x, minMS,
#                 color="white", alpha=0.4)

plt.plot(x,meanMS*100.0,label='Near-Future Ensemble Mean', color='red')
plt.plot(x,histEns*100.0,label='Historical Ensemble Mean', color='blue')

plt.ylim([0, 70])
    
plt.xlabel('Day of season')
plt.ylabel('Widespread Fog Occurances')     
plt.legend()    
plt.savefig('WFD_SC_245_2015-2065.eps')
#plt.savefig('FogFraction_SC_legend.eps')
plt.show()
##plt.legend() 

#print('\n'.join(map(str, meanMS*100.0)))
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ACCESS-CM2
# IITM-ESM
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# EC-Earth3
# 0.094736844

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
y.values=y.where(y>=0.46,0)
y.values=y.where(y==0.0,1)
CNN.values=CNN.where(CNN>=0.46,0)
CNN.values=CNN.where(CNN==0.0,1)

OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]


CNNTs1=getSeasonalCycle(CNN)
CNNTs2=CNNTs1.roll(dayofyear=31)
CNNTs=CNNTs2[(CNNTs2.dayofyear<366) | (CNNTs2.dayofyear>366)]
CNNTs

MTs=[]

classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']


for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp370/Modelplots_future/'+cL+'_ssp370.joblib')
    fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
    fL1.values=fL1.where(fL1>=0.46,0)
    fL1.values=fL1.where(fL1==0.0,1)
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))
    MTs.append(ts)
MS=np.array(MTs)
print(np.mean(MS[:,61]))

meanMS=np.mean(MS, axis=0)
minMS=np.amin(MS,axis=0)
maxMS=np.amax(MS,axis=0)

plt.plot(x,OTs*100.0,label='Obs', color='black')
plt.plot(x,CNNTs*100.0,label='CNN', color='orange')

plt.fill_between(x, maxMS*100.0,minMS*100.0,
                 color="skyblue", alpha=0.4,label='Spread of the models')
#plt.fill_between(x, minMS,
#                 color="white", alpha=0.4)

plt.plot(x,meanMS*100.0,label='Near-Future Ensemble Mean', color='red')
plt.plot(x,histEns*100.0,label='Historical Ensemble Mean', color='blue')

plt.ylim([0, 70])
    
plt.xlabel('Day of season')
plt.ylabel('Widespread Fog Occurances')     
plt.legend()    
plt.savefig('WFD_SC_370_2015-2065.eps')
#plt.savefig('FogFraction_SC_legend.eps')
plt.show()
##plt.legend() 

#print('\n'.join(map(str, meanMS*100.0)))
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ACCESS-CM2
# IITM-ESM
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# EC-Earth3
# 0.14210527

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
y.values=y.where(y>=0.46,0)
y.values=y.where(y==0.0,1)
CNN.values=CNN.where(CNN>=0.46,0)
CNN.values=CNN.where(CNN==0.0,1)

OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]


CNNTs1=getSeasonalCycle(CNN)
CNNTs2=CNNTs1.roll(dayofyear=31)
CNNTs=CNNTs2[(CNNTs2.dayofyear<366) | (CNNTs2.dayofyear>366)]
CNNTs

MTs=[]

classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']


for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp585/Modelplots_future/'+cL+'_ssp585.joblib')
    fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
    fL1.values=fL1.where(fL1>=0.46,0)
    fL1.values=fL1.where(fL1==0.0,1)
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))
    MTs.append(ts)
MS=np.array(MTs)
print(np.mean(MS[:,61]))

meanMS=np.mean(MS, axis=0)
minMS=np.amin(MS,axis=0)
maxMS=np.amax(MS,axis=0)

plt.plot(x,OTs*100.0,label='Obs', color='black')
plt.plot(x,CNNTs*100.0,label='CNN', color='orange')

plt.fill_between(x, maxMS*100.0,minMS*100.0,
                 color="skyblue", alpha=0.4,label='Spread of the models')
#plt.fill_between(x, minMS,
#                 color="white", alpha=0.4)

plt.plot(x,meanMS*100.0,label='Near-Future Ensemble Mean', color='red')
plt.plot(x,histEns*100.0,label='Historical Ensemble Mean', color='blue')

plt.ylim([0, 70])
    
plt.xlabel('Day of season')
plt.ylabel('Widespread Fog Occurances')     
plt.legend()    
plt.savefig('WFD_SC_585_2015-2065.eps')
#plt.savefig('FogFraction_SC_legend.eps')
plt.show()
##plt.legend() 
#print('\n'.join(map(str, meanMS*100.0)))
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ACCESS-CM2
# IITM-ESM
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# EC-Earth3
# 0.078947365

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
y.values=y.where(y>=0.46,0)
y.values=y.where(y==0.0,1)
CNN.values=CNN.where(CNN>=0.46,0)
CNN.values=CNN.where(CNN==0.0,1)

OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]


CNNTs1=getSeasonalCycle(CNN)
CNNTs2=CNNTs1.roll(dayofyear=31)
CNNTs=CNNTs2[(CNNTs2.dayofyear<366) | (CNNTs2.dayofyear>366)]
CNNTs

MTs=[]

classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']


for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp585/Modelplots_future/'+cL+'_ssp585.joblib')
    fL1=fL.sel(time=slice('2066-1-1','2100-12-31'))
    fL1.values=fL1.where(fL1>=0.46,0)
    fL1.values=fL1.where(fL1==0.0,1)
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))
    MTs.append(ts)
MS=np.array(MTs)
print(np.mean(MS[:,61]))

meanMS=np.mean(MS, axis=0)
minMS=np.amin(MS,axis=0)
maxMS=np.amax(MS,axis=0)

plt.plot(x,OTs*100.0,label='Obs', color='black')
plt.plot(x,CNNTs*100.0,label='CNN', color='orange')

plt.fill_between(x, maxMS*100.0,minMS*100.0,
                 color="skyblue", alpha=0.4,label='Spread of the models')
#plt.fill_between(x, minMS,
#                 color="white", alpha=0.4)

plt.plot(x,meanMS*100.0,label='Far-Future Ensemble Mean', color='red')
plt.plot(x,histEns*100.0,label='Historical Ensemble Mean', color='blue')

plt.ylim([0, 70])
    
plt.xlabel('Day of season')
plt.ylabel('Widespread Fog Occurances')     
plt.legend()    
plt.savefig('WFD_SC_585_2066-2100.eps')
#plt.savefig('FogFraction_SC_legend.eps')
plt.show()
##plt.legend() 
#print('\n'.join(map(str, meanMS*100.0)))
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ACCESS-CM2
# IITM-ESM
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# EC-Earth3
# 0.037037037

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
y.values=y.where(y>=0.46,0)
y.values=y.where(y==0.0,1)
CNN.values=CNN.where(CNN>=0.46,0)
CNN.values=CNN.where(CNN==0.0,1)

OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]


CNNTs1=getSeasonalCycle(CNN)
CNNTs2=CNNTs1.roll(dayofyear=31)
CNNTs=CNNTs2[(CNNTs2.dayofyear<366) | (CNNTs2.dayofyear>366)]
CNNTs

MTs=[]

classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']


for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp126/Modelplots_future/'+cL+'_ssp126.joblib')
    fL1=fL.sel(time=slice('2066-1-1','2100-12-31'))
    fL1.values=fL1.where(fL1>=0.46,0)
    fL1.values=fL1.where(fL1==0.0,1)
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))
    MTs.append(ts)
MS=np.array(MTs)
print(np.mean(MS[:,61]))

meanMS=np.mean(MS, axis=0)
minMS=np.amin(MS,axis=0)
maxMS=np.amax(MS,axis=0)

plt.plot(x,OTs*100.0,label='Obs', color='black')
plt.plot(x,CNNTs*100.0,label='CNN', color='orange')

plt.fill_between(x, maxMS*100.0,minMS*100.0,
                 color="skyblue", alpha=0.4,label='Spread of the models')
#plt.fill_between(x, minMS,
#                 color="white", alpha=0.4)

plt.plot(x,meanMS*100.0,label='Far-Future Ensemble Mean', color='red')
plt.plot(x,histEns*100.0,label='Historical Ensemble Mean', color='blue')

plt.ylim([0, 70])
    
plt.xlabel('Day of season')
plt.ylabel('Widespread Fog Occurances')     
plt.legend()    
plt.savefig('WFD_SC_126_2066-2100.eps')
#plt.savefig('FogFraction_SC_legend.eps')
plt.show()
##plt.legend() 
#print('\n'.join(map(str, meanMS*100.0)))
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ACCESS-CM2
# IITM-ESM
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# EC-Earth3
# 0.10455841

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
y.values=y.where(y>=0.46,0)
y.values=y.where(y==0.0,1)
CNN.values=CNN.where(CNN>=0.46,0)
CNN.values=CNN.where(CNN==0.0,1)

OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]


CNNTs1=getSeasonalCycle(CNN)
CNNTs2=CNNTs1.roll(dayofyear=31)
CNNTs=CNNTs2[(CNNTs2.dayofyear<366) | (CNNTs2.dayofyear>366)]
CNNTs

MTs=[]

classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']


for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp370/Modelplots_future/'+cL+'_ssp370.joblib')
    fL1=fL.sel(time=slice('2066-1-1','2100-12-31'))
    fL1.values=fL1.where(fL1>=0.46,0)
    fL1.values=fL1.where(fL1==0.0,1)
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))
    MTs.append(ts)
MS=np.array(MTs)
print(np.mean(MS[:,61]))

meanMS=np.mean(MS, axis=0)
minMS=np.amin(MS,axis=0)
maxMS=np.amax(MS,axis=0)

plt.plot(x,OTs*100.0,label='Obs', color='black')
plt.plot(x,CNNTs*100.0,label='CNN', color='orange')

plt.fill_between(x, maxMS*100.0,minMS*100.0,
                 color="skyblue", alpha=0.4,label='Spread of the models')
#plt.fill_between(x, minMS,
#                 color="white", alpha=0.4)

plt.plot(x,meanMS*100.0,label='Far-Future Ensemble Mean', color='red')
plt.plot(x,histEns*100.0,label='Historical Ensemble Mean', color='blue')

plt.ylim([0, 70])
    
plt.xlabel('Day of season')
plt.ylabel('Widespread Fog Occurances')     
plt.legend()    
plt.savefig('WFD_SC_370_2066-2100.eps')
#plt.savefig('FogFraction_SC_legend.eps')
plt.show()
##plt.legend() 

#print('\n'.join(map(str, meanMS*100.0)))
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ACCESS-CM2
# IITM-ESM
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# EC-Earth3
# 0.074074075

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
y.values=y.where(y>=0.46,0)
y.values=y.where(y==0.0,1)
CNN.values=CNN.where(CNN>=0.46,0)
CNN.values=CNN.where(CNN==0.0,1)

OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]


CNNTs1=getSeasonalCycle(CNN)
CNNTs2=CNNTs1.roll(dayofyear=31)
CNNTs=CNNTs2[(CNNTs2.dayofyear<366) | (CNNTs2.dayofyear>366)]
CNNTs

MTs=[]

classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']


for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp245/Modelplots_future/'+cL+'_ssp245.joblib')
    fL1=fL.sel(time=slice('2066-1-1','2100-12-31'))
    fL1.values=fL1.where(fL1>=0.46,0)
    fL1.values=fL1.where(fL1==0.0,1)
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))
    MTs.append(ts)
MS=np.array(MTs)
print(np.mean(MS[:,61]))

meanMS=np.mean(MS, axis=0)
minMS=np.amin(MS,axis=0)
maxMS=np.amax(MS,axis=0)

plt.plot(x,OTs*100.0,label='Obs', color='black')
plt.plot(x,CNNTs*100.0,label='CNN', color='orange')

plt.fill_between(x, maxMS*100.0,minMS*100.0,
                 color="skyblue", alpha=0.4,label='Spread of the models')
#plt.fill_between(x, minMS,
#                 color="white", alpha=0.4)

plt.plot(x,meanMS*100.0,label='Far-Future Ensemble Mean', color='red')
plt.plot(x,histEns*100.0,label='Historical Ensemble Mean', color='blue')

plt.ylim([0, 70])
    
plt.xlabel('Day of season')
plt.ylabel('Widespread Fog Occurances')     
plt.legend()    
plt.savefig('WFD_SC_245_2066-2100.eps')
#plt.savefig('FogFraction_SC_legend.eps')
plt.show()
##plt.legend() 
#print('\n'.join(map(str, meanMS*100.0)))
#print('\n'.join(map(str, OTs.values*100.0)))
#print('\n'.join(map(str, CNNTs.values*100.0)))
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ACCESS-CM2
# IITM-ESM
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# EC-Earth3
# 0.06752137

# %% [raw]
# #fig = plt.figure(figsize=(20,10))
# fig = plt.figure(figsize=(10,6))
# x=np.arange(1,63)
# #fMean=list()
# fCC=list()
# OTs1=getSeasonalCycle(y)
# OTs2=OTs1.roll(dayofyear=31)
# OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
# classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
# class_colours = ['red','chocolate','lime','plum','grey']
#
# # Obs
# ts1=getSeasonalCycle(y)
#
# ts2=ts1.roll(dayofyear=31)
# ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
#     #print(xr.corr(ts, OTs))
#
#     #fMean.append((ts))
# plt.plot(x,ts,label='obs', color='black')
#
# for ( cL, cO) in zip(classes,class_colours):
#     fL=load('../../April2021/New_ssp585/Modelplots_future/'+cL+'_ssp585.joblib')
#
#     fL1=fL.sel(time=slice('2066-1-1','2100-12-31'))
#     fL1.values=fL1.where(fL1>=0.46,0)
#     fL1.values=fL1.where(fL1==0.0,1)
#     ts1=getSeasonalCycle(fL1)
#     print(cL)
#     ts2=ts1.roll(dayofyear=31)
#     ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
#     #print(xr.corr(ts, OTs))
#     fCC.append(xr.corr(ts, OTs))
#     #fMean.append((ts))
#    # plt.plot(x,ts,label=cL+'_2', color=cO,  linestyle='--')
#     plt.plot(x,ts, color=cO,  linestyle='-')
#     plt.ylim(-0.01,0.6)
#
# plt.xlabel('Day of season')
# plt.ylabel('Probability of being widespread fog day')
# #plt.legend()
# print(fCC)
# plt.savefig('FarFuture_WFD_SC_585.eps')
# #plt.savefig('FogFraction_SC_legend.eps')
# plt.show()
# ##plt.legend()
