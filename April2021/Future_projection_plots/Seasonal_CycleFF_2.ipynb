# %%
import xarray as xr
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from joblib import dump, load
import statistics as st

# %%
y   = load('../../March2021/Observation_models/ObsY.joblib')

# %%
def getSeasonalCycle( dArray ):
   #"This function gives TS of categories of each type for each season e.g. if year
   #  is 1981 then it will contain values between 1dec1980 to 31jan1981"
    fg=dArray.groupby('time.dayofyear').mean()
    
    
    
    return fg

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']

# Obs
ts1=getSeasonalCycle(y)
    
ts2=ts1.roll(dayofyear=31)
tso=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))

    #fMean.append((ts))
#plt.plot(x,ts,label='obs', color='black')

for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp126/Modelplots_future/'+cL+'_ssp126.joblib')
    fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    ts=ts-tso
    print(cL)
    plt.plot(x,ts,label=cL, color=cO,  linestyle='-')
    #plt.ylim(0.1,0.5)
    #plt.ylim(0.1,0.5) 
plt.xlabel('Day of season')
plt.ylabel('Absolute Change in Mean Fog Fraction')     
#plt.legend()
print(fCC)
plt.savefig('NearFuture_FFChange_SC_126.png')
#plt.savefig('FogFraction_SC_legend.png')
plt.show()
##plt.legend()
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# ACCESS-CM2
# ACCESS-CM2
# IITM-ESM
# IITM-ESM
# IPSL-CM6A-LR
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# MPI-ESM1-2-LR
# EC-Earth3
# EC-Earth3
# []

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']

# Obs
ts1=getSeasonalCycle(y)
    
ts2=ts1.roll(dayofyear=31)
tso=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))

    #fMean.append((ts))
#plt.plot(x,ts,label='obs', color='black')

for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp126/Modelplots_future/'+cL+'_ssp126.joblib')
    fL1=fL.sel(time=slice('2066-1-1','2100-12-31'))
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    ts=ts-tso
    print(cL)
    plt.plot(x,ts,label=cL, color=cO,  linestyle='-')
    #plt.ylim(0.1,0.5)
    #plt.ylim(0.1,0.5) 
plt.xlabel('Day of season')
plt.ylabel('Absolute Change in Mean Fog Fraction')     
#plt.legend()
print(fCC)
plt.savefig('FarFuture_FFChange_SC_126.png')
#plt.savefig('FogFraction_SC_legend.png')
plt.show()
##plt.legend()
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# ACCESS-CM2
# ACCESS-CM2
# IITM-ESM
# IITM-ESM
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# IPSL-CM6A-LR
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# MPI-ESM1-2-LR
# EC-Earth3
# EC-Earth3
# []
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']

# Obs
ts1=getSeasonalCycle(y)
    
ts2=ts1.roll(dayofyear=31)
tso=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))

    #fMean.append((ts))
#plt.plot(x,ts,label='obs', color='black')

for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp245/Modelplots_future/'+cL+'_ssp245.joblib')
    fL1=fL.sel(time=slice('2066-1-1','2100-12-31'))
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    ts=ts-tso
    print(cL)
    plt.plot(x,ts,label=cL, color=cO,  linestyle='-')
    #plt.ylim(0.1,0.5)
    #plt.ylim(0.1,0.5) 
plt.xlabel('Day of season')
plt.ylabel('Absolute Change in Mean Fog Fraction')     
#plt.legend()
print(fCC)
plt.savefig('FarFuture_FFChange_SC_245.png')
#plt.savefig('FogFraction_SC_legend.png')
plt.show()
##plt.legend()
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# ACCESS-CM2
# ACCESS-CM2
# IITM-ESM
# IITM-ESM
# IPSL-CM6A-LR
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# MPI-ESM1-2-LR
# EC-Earth3
# EC-Earth3
# []
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']

# Obs
ts1=getSeasonalCycle(y)
    
ts2=ts1.roll(dayofyear=31)
tso=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))

    #fMean.append((ts))
#plt.plot(x,ts,label='obs', color='black')

for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp245/Modelplots_future/'+cL+'_ssp245.joblib')
    fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    ts=ts-tso
    print(cL)
    plt.plot(x,ts,label=cL, color=cO,  linestyle='-')
    #plt.ylim(0.1,0.5)
    #plt.ylim(0.1,0.5) 
plt.xlabel('Day of season')
plt.ylabel('Absolute Change in Mean Fog Fraction')     
#plt.legend()
print(fCC)
plt.savefig('NearFuture_FFChange_SC_245.png')
#plt.savefig('FogFraction_SC_legend.png')
plt.show()
##plt.legend()
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# ACCESS-CM2
# ACCESS-CM2
# IITM-ESM
# IITM-ESM
# IPSL-CM6A-LR
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# MPI-ESM1-2-LR
# EC-Earth3
# EC-Earth3
# []

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']

# Obs
ts1=getSeasonalCycle(y)
    
ts2=ts1.roll(dayofyear=31)
tso=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))

    #fMean.append((ts))
#plt.plot(x,ts,label='obs', color='black')

for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp370/Modelplots_future/'+cL+'_ssp370.joblib')
    fL1=fL.sel(time=slice('2066-1-1','2100-12-31'))
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    ts=ts-tso
    print(cL)
    plt.plot(x,ts,label=cL, color=cO,  linestyle='-')
    #plt.ylim(0.1,0.5)
    #plt.ylim(0.1,0.5) 
plt.xlabel('Day of season')
plt.ylabel('Absolute Change in Mean Fog Fraction')     
#plt.legend()
print(fCC)
plt.savefig('FarFuture_FFChange_SC_370.png')
#plt.savefig('FogFraction_SC_legend.png')
plt.show()
##plt.legend()
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# ACCESS-CM2
# ACCESS-CM2
# IITM-ESM
# IITM-ESM
# IPSL-CM6A-LR
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# MPI-ESM1-2-LR
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# EC-Earth3
# EC-Earth3
# []

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']

# Obs
ts1=getSeasonalCycle(y)
    
ts2=ts1.roll(dayofyear=31)
tso=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))

    #fMean.append((ts))
#plt.plot(x,ts,label='obs', color='black')

for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp370/Modelplots_future/'+cL+'_ssp370.joblib')
    fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    ts=ts-tso
    print(cL)
    plt.plot(x,ts,label=cL, color=cO,  linestyle='-')
    #plt.ylim(0.1,0.5)
    #plt.ylim(0.1,0.5) 
plt.xlabel('Day of season')
plt.ylabel('Absolute Change in Mean Fog Fraction')     
#plt.legend()
print(fCC)
plt.savefig('NearFuture_FFChange_SC_370.png')
#plt.savefig('FogFraction_SC_legend.png')
plt.show()
##plt.legend()
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# ACCESS-CM2
# ACCESS-CM2
# IITM-ESM
# IITM-ESM
# IPSL-CM6A-LR
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# MPI-ESM1-2-LR
# EC-Earth3
# EC-Earth3
# []

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']

# Obs
ts1=getSeasonalCycle(y)
    
ts2=ts1.roll(dayofyear=31)
tso=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))

    #fMean.append((ts))
#plt.plot(x,ts,label='obs', color='black')

for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp585/Modelplots_future/'+cL+'_ssp585.joblib')
    fL1=fL.sel(time=slice('2066-1-1','2100-12-31'))
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    ts=ts-tso
    print(cL)
    plt.plot(x,ts,label=cL, color=cO,  linestyle='-')
    #plt.ylim(0.1,0.5)
    #plt.ylim(0.1,0.5) 
plt.xlabel('Day of season')
plt.ylabel('Absolute Change in Mean Fog Fraction')     
#plt.legend()
print(fCC)
plt.savefig('FarFuture_FFChange_SC_585.png')
#plt.savefig('FogFraction_SC_legend.png')
plt.show()
##plt.legend()
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# ACCESS-CM2
# ACCESS-CM2
# IITM-ESM
# IITM-ESM
# IPSL-CM6A-LR
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# MPI-ESM1-2-LR
# EC-Earth3
# EC-Earth3
# []
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(

# %%
#fig = plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,6))
x=np.arange(1,63)
#fMean=list()
fCC=list()
OTs1=getSeasonalCycle(y)
OTs2=OTs1.roll(dayofyear=31)
OTs=OTs2[(OTs2.dayofyear<366) | (OTs2.dayofyear>366)]
classes = ['ACCESS-CM2','IITM-ESM','IPSL-CM6A-LR','MPI-ESM1-2-LR','EC-Earth3']
class_colours = ['red','chocolate','lime','plum','grey']

# Obs
ts1=getSeasonalCycle(y)
    
ts2=ts1.roll(dayofyear=31)
tso=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    #print(xr.corr(ts, OTs))

    #fMean.append((ts))
#plt.plot(x,ts,label='obs', color='black')

for ( cL, cO) in zip(classes,class_colours):
    fL=load('../../April2021/New_ssp585/Modelplots_future/'+cL+'_ssp585.joblib')
    fL1=fL.sel(time=slice('2015-1-1','2065-12-31'))
    ts1=getSeasonalCycle(fL1)
    print(cL)
    ts2=ts1.roll(dayofyear=31)
    ts=ts2[(ts2.dayofyear<366) | (ts2.dayofyear>366)]
    ts=ts-tso
    print(cL)
    plt.plot(x,ts,label=cL, color=cO,  linestyle='-')
    #plt.ylim(0.1,0.5)
    #plt.ylim(0.1,0.5) 
plt.xlabel('Day of season')
plt.ylabel('Absolute Change in Mean Fog Fraction')     
#plt.legend()
print(fCC)
plt.savefig('NearFuture_FFChange_SC_585.png')
#plt.savefig('FogFraction_SC_legend.png')
plt.show()
##plt.legend()
# Out:
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# /home/cccr/diptih/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py:3127: FutureWarning: roll_coords will be set to False in the future. Explicitly set roll_coords to silence warning.
#   ds = self._to_temp_dataset().roll(
# ACCESS-CM2
# ACCESS-CM2
# IITM-ESM
# IITM-ESM
# IPSL-CM6A-LR
# IPSL-CM6A-LR
# MPI-ESM1-2-LR
# MPI-ESM1-2-LR
# EC-Earth3
# EC-Earth3
# []
