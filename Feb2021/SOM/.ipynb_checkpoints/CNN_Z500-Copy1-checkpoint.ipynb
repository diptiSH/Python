# %%
import xarray as xr
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten,MaxPooling2D,AveragePooling2D, concatenate,Input

from math import e
from sklearn.model_selection import train_test_split
from keras.models import Model

# %%
fogData = xr.open_dataset('../../../Data/FogData/CombinedFogData_25Stations.nc')
#plt.figure(figsize=[16,8])
StackFog=fogData.fogdata.stack(a=('years','months','days'))
StackFog
dd =[];
for i in range(StackFog.years.values.shape[0]):
    dd=dd+[str(StackFog.years[i].values)+'-'+str(StackFog.months[i].values)+"-"+str(StackFog.days[i].values)]
fg = xr.Dataset({'fogdata': (('time','stations'), StackFog.values.T)}, coords={'time': pd.to_datetime(dd),'stations': fogData.stations})
y=fg.fogdata.sum(dim='stations').sel(time=slice('1980-1-1','2014-12-31'))
y=y/25.0
#y

# %%
z500Data = xr.open_dataset('../../../Data/eraDown/ERA5_2degree_Down/DailyMean/StdAnomERA5NH_500_z_daily_NovDecJan.nc')

# %%
z=z500Data.z.shift(time=1)

# %%
zTs=z[((z.time.dt.month>11) | (z.time.dt.month<2)) & (z.time.dt.year<2020)].sel(time=slice('1980-1-1','2014-12-31'),latitude=slice(90,0),longitude=slice(0,120))

# %%
z_train, z_test, y_train,y_test = train_test_split( zTs, y,test_size=0.20, random_state=0)

# %%
ztrain=z_train.values
ztrain=ztrain[:,:,:,None]
ztrain.shape
ytrain=y_train.values
ytrain=ytrain[:,None]
ytrain.shape
ztest=z_test.values
ztest=ztest[:,:,:,None]
ztest.shape
ytest=y_test.values
ytest=ytest[:,None]
ytest.shape
# Out:
# (434, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten,MaxPooling2D,AveragePooling2D

model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(7 ,7), activation='relu', input_shape=(ztrain.shape[1],ztrain.shape[2],1)))
model.add(MaxPooling2D())

model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D())

#model.add(Conv2D(filters=256, kernel_size=(1,1), activation='relu'))
#model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu'))
#model.add(Conv2D(filters=3, kernel_size=(1, 1), activation='relu'))
#model.add(AveragePooling2D())

model.add(Flatten())

model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=60, activation='relu'))
model.add(Dense(units=40, activation='relu'))
#model.add(Dense(units=20, activation='relu'))

model.add(Dense(units=1, activation = 'linear'))
model.compile(optimizer='adam', loss='mae')

history = model.fit(ztrain, ytrain, validation_data=(ztest, ytest), epochs=100)
yy_test = model.predict(ztest)

test_corr = np.corrcoef(yy_test[:,0],y_test)[0,1]
plt.title('corr = %f'%test_corr)

plt.plot(yy_test,ytest,'+')
#y_test
# Out:
# Epoch 1/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.1876 - val_loss: 0.1720
# Epoch 2/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.1723 - val_loss: 0.1649
# Epoch 3/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.1612 - val_loss: 0.1629
# Epoch 4/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.1572 - val_loss: 0.1649
# Epoch 5/100
# 55/55 [==============================] - 2s 31ms/step - loss: 0.1614 - val_loss: 0.1674
# Epoch 6/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.1649 - val_loss: 0.1660
# Epoch 7/100
# 55/55 [==============================] - 2s 31ms/step - loss: 0.1507 - val_loss: 0.1608
# Epoch 8/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.1460 - val_loss: 0.1629
# Epoch 9/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.1495 - val_loss: 0.1655
# Epoch 10/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.1374 - val_loss: 0.1616
# Epoch 11/100
# 55/55 [==============================] - 2s 31ms/step - loss: 0.1286 - val_loss: 0.1620
# Epoch 12/100
# 55/55 [==============================] - 2s 31ms/step - loss: 0.1230 - val_loss: 0.1622
# Epoch 13/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.1114 - val_loss: 0.1616
# Epoch 14/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.1195 - val_loss: 0.1597
# Epoch 15/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1052 - val_loss: 0.1540
# Epoch 16/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1015 - val_loss: 0.1572
# Epoch 17/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0959 - val_loss: 0.1496
# Epoch 18/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0912 - val_loss: 0.1498
# Epoch 19/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0803 - val_loss: 0.1486
# Epoch 20/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0764 - val_loss: 0.1521
# Epoch 21/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0744 - val_loss: 0.1507
# Epoch 22/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0713 - val_loss: 0.1448
# Epoch 23/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0656 - val_loss: 0.1462
# Epoch 24/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0636 - val_loss: 0.1460
# Epoch 25/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0607 - val_loss: 0.1464
# Epoch 26/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0568 - val_loss: 0.1366
# Epoch 27/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0579 - val_loss: 0.1450
# Epoch 28/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0575 - val_loss: 0.1453
# Epoch 29/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0534 - val_loss: 0.1420
# Epoch 30/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0490 - val_loss: 0.1390
# Epoch 31/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0447 - val_loss: 0.1426
# Epoch 32/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0458 - val_loss: 0.1364
# Epoch 33/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0442 - val_loss: 0.1411
# Epoch 34/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0488 - val_loss: 0.1402
# Epoch 35/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0429 - val_loss: 0.1404
# Epoch 36/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0420 - val_loss: 0.1368
# Epoch 37/100
# 55/55 [==============================] - 1s 22ms/step - loss: 0.0406 - val_loss: 0.1377
# Epoch 38/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0409 - val_loss: 0.1403
# Epoch 39/100
# 55/55 [==============================] - 1s 23ms/step - loss: 0.0417 - val_loss: 0.1360
# Epoch 40/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0382 - val_loss: 0.1441
# Epoch 41/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0392 - val_loss: 0.1392
# Epoch 42/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0378 - val_loss: 0.1365
# Epoch 43/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0338 - val_loss: 0.1356
# Epoch 44/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0337 - val_loss: 0.1359
# Epoch 45/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0329 - val_loss: 0.1357
# Epoch 46/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0313 - val_loss: 0.1376
# Epoch 47/100
# 55/55 [==============================] - 2s 36ms/step - loss: 0.0334 - val_loss: 0.1346
# Epoch 48/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0299 - val_loss: 0.1386
# Epoch 49/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0291 - val_loss: 0.1390
# Epoch 50/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0276 - val_loss: 0.1374
# Epoch 51/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0281 - val_loss: 0.1380
# Epoch 52/100
# 55/55 [==============================] - 2s 31ms/step - loss: 0.0304 - val_loss: 0.1339
# Epoch 53/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0291 - val_loss: 0.1340
# Epoch 54/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0291 - val_loss: 0.1330
# Epoch 55/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0280 - val_loss: 0.1383
# Epoch 56/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0274 - val_loss: 0.1353
# Epoch 57/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0274 - val_loss: 0.1312
# Epoch 58/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0271 - val_loss: 0.1370
# Epoch 59/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0286 - val_loss: 0.1370
# Epoch 60/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0285 - val_loss: 0.1346
# Epoch 61/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0293 - val_loss: 0.1320
# Epoch 62/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0244 - val_loss: 0.1361
# Epoch 63/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0241 - val_loss: 0.1333
# Epoch 64/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0268 - val_loss: 0.1355
# Epoch 65/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0253 - val_loss: 0.1357
# Epoch 66/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0252 - val_loss: 0.1354
# Epoch 67/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0240 - val_loss: 0.1350
# Epoch 68/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0246 - val_loss: 0.1345
# Epoch 69/100
# 55/55 [==============================] - 2s 36ms/step - loss: 0.0236 - val_loss: 0.1317
# Epoch 70/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0227 - val_loss: 0.1334
# Epoch 71/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0230 - val_loss: 0.1326
# Epoch 72/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0223 - val_loss: 0.1330
# Epoch 73/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0257 - val_loss: 0.1349
# Epoch 74/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0215 - val_loss: 0.1349
# Epoch 75/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0213 - val_loss: 0.1343
# Epoch 76/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0225 - val_loss: 0.1343
# Epoch 77/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0222 - val_loss: 0.1383
# Epoch 78/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0216 - val_loss: 0.1397
# Epoch 79/100
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0240 - val_loss: 0.1378
# Epoch 80/100
# 55/55 [==============================] - 5s 86ms/step - loss: 0.0219 - val_loss: 0.1342
# Epoch 81/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0234 - val_loss: 0.1355
# Epoch 82/100
# 55/55 [==============================] - 2s 36ms/step - loss: 0.0208 - val_loss: 0.1353
# Epoch 83/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0207 - val_loss: 0.1337
# Epoch 84/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0196 - val_loss: 0.1367
# Epoch 85/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0210 - val_loss: 0.1342
# Epoch 86/100
# 55/55 [==============================] - 2s 36ms/step - loss: 0.0221 - val_loss: 0.1346
# Epoch 87/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0215 - val_loss: 0.1358
# Epoch 88/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0228 - val_loss: 0.1369
# Epoch 89/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0216 - val_loss: 0.1327
# Epoch 90/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0205 - val_loss: 0.1319
# Epoch 91/100
# 55/55 [==============================] - 2s 37ms/step - loss: 0.0217 - val_loss: 0.1331
# Epoch 92/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0198 - val_loss: 0.1339
# Epoch 93/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0207 - val_loss: 0.1349
# Epoch 94/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0213 - val_loss: 0.1338
# Epoch 95/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0209 - val_loss: 0.1347
# Epoch 96/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0209 - val_loss: 0.1338
# Epoch 97/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0200 - val_loss: 0.1341
# Epoch 98/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0197 - val_loss: 0.1346
# Epoch 99/100
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0186 - val_loss: 0.1340
# Epoch 100/100
# 55/55 [==============================] - 2s 35ms/step - loss: 0.0185 - val_loss: 0.1350

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten,MaxPooling2D,AveragePooling2D

model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(7 ,7), activation='relu', input_shape=(ztrain.shape[1],ztrain.shape[2],1)))
model.add(MaxPooling2D())

model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=256, kernel_size=(1,1), activation='relu'))
#model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu'))
#model.add(Conv2D(filters=3, kernel_size=(1, 1), activation='relu'))
#model.add(AveragePooling2D())

model.add(Flatten())

model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=60, activation='relu'))
model.add(Dense(units=40, activation='relu'))
#model.add(Dense(units=20, activation='relu'))

model.add(Dense(units=1, activation = 'linear'))
model.compile(optimizer='adam', loss='mae')

history = model.fit(ztrain, ytrain, validation_data=(ztest, ytest), epochs=9)
yy_test = model.predict(ztest)

test_corr = np.corrcoef(yy_test[:,0],y_test)[0,1]
plt.title('corr = %f'%test_corr)

plt.plot(yy_test,ytest,'+')
#y_test
