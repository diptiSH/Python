# %%
import numpy as np
import pandas as pd
import xarray as xr
import math as mt
from joblib import dump, load
import datetime
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Case 1

# %%
obs = load('TS2dataObs_1.joblib') 
LR= load('TS2dataLR_1.joblib')
SVR=load('TS2dataSVR_1.joblib')
GB=load('TS2dataGB_1.joblib')
CNN=load('TS2dataCNN_1.joblib')


plt.figure(figsize=[15,5])
obs.resample(time='1Y').mean().plot(label='Obs')
LR.resample(time='1Y').mean().plot(label='Pred_LR')
SVR.resample(time='1Y').mean().plot(label='Pred_SVR')
GB.resample(time='1Y').mean().plot(label='Pred_GB')
CNN.resample(time='1Y').mean().plot(label='Pred_CNN')
plt.ylim(0, 0.6)
plt.legend()
plt.savefig('NOAOEU_TS2_Case1.jpeg')
plt.show()

# %%
obs = load('TS1dataObs_1.joblib') 
LR= load('TS1dataLR_1.joblib')
SVR=load('TS1dataSVR_1.joblib')
GB=load('TS1dataGB_1.joblib')
CNN=load('TS1dataCNN_1.joblib')


plt.figure(figsize=[15,5])
obs.resample(time='1Y').mean().plot(label='Obs')
LR.resample(time='1Y').mean().plot(label='Pred_LR')
SVR.resample(time='1Y').mean().plot(label='Pred_SVR')
GB.resample(time='1Y').mean().plot(label='Pred_GB')
CNN.resample(time='1Y').mean().plot(label='Pred_CNN')
plt.ylim(0, 0.6)
plt.legend()
plt.savefig('NOAOEU_TS1_Case1.jpeg')
plt.show()

# %% [markdown]
# # Case 2

# %%
obs = load('TS2dataObs_2.joblib') 
LR= load('TS2dataLR_2.joblib')
SVR=load('TS2dataSVR_2.joblib')
GB=load('TS2dataGB_2.joblib')
CNN=load('TS2dataCNN_2.joblib')


plt.figure(figsize=[15,5])
obs.resample(time='1Y').mean().plot(label='Obs')
LR.resample(time='1Y').mean().plot(label='Pred_LR')
SVR.resample(time='1Y').mean().plot(label='Pred_SVR')
GB.resample(time='1Y').mean().plot(label='Pred_GB')
CNN.resample(time='1Y').mean().plot(label='Pred_CNN')
plt.ylim(0, 0.6)
plt.legend()
plt.savefig('NOAOEU_TS2_Case2.jpeg')
plt.show()

# %%
obs = load('TS1dataObs_2.joblib') 
LR= load('TS1dataLR_2.joblib')
SVR=load('TS1dataSVR_2.joblib')
GB=load('TS1dataGB_2.joblib')
CNN=load('TS1dataCNN_2.joblib')


plt.figure(figsize=[15,5])
obs.resample(time='1Y').mean().plot(label='Obs')
LR.resample(time='1Y').mean().plot(label='Pred_LR')
SVR.resample(time='1Y').mean().plot(label='Pred_SVR')
GB.resample(time='1Y').mean().plot(label='Pred_GB')
CNN.resample(time='1Y').mean().plot(label='Pred_CNN')
plt.ylim(0, 0.6)
plt.legend()
plt.savefig('NOAOEU_TS1_Case2.jpeg')
plt.show()

# %% [markdown]
# # Case 3

# %%
obs = load('TS1dataObs_3.joblib') 
LR= load('TS1dataLR_3.joblib')
SVR=load('TS1dataSVR_3.joblib')
GB=load('TS1dataGB_3.joblib')
CNN=load('TS1dataCNN_3.joblib')


plt.figure(figsize=[15,5])
obs.resample(time='1Y').mean().plot(label='Obs')
LR.resample(time='1Y').mean().plot(label='Pred_LR')
SVR.resample(time='1Y').mean().plot(label='Pred_SVR')
GB.resample(time='1Y').mean().plot(label='Pred_GB')
CNN.resample(time='1Y').mean().plot(label='Pred_CNN')
plt.ylim(0, 0.6)
plt.legend()
plt.savefig('NOAOEU_TS1_Case3.jpeg')
plt.show()

# %%
obs = load('TS2dataObs_3.joblib') 
LR= load('TS2dataLR_3.joblib')
SVR=load('TS2dataSVR_3.joblib')
GB=load('TS2dataGB_3.joblib')
CNN=load('TS2dataCNN_3.joblib')

fig = plt.figure(figsize=[15,5])
ax = fig.add_subplot(122)
obs.sel(time=slice('2015-1-1','2018-12-31')).resample(time='1Y').mean().plot(label='Obs')
LR.sel(time=slice('2015-1-1','2018-12-31')).resample(time='1Y').mean().plot(label='Pred_LR')
SVR.sel(time=slice('2015-1-1','2018-12-31')).resample(time='1Y').mean().plot(label='Pred_SVR')
GB.sel(time=slice('2015-1-1','2018-12-31')).resample(time='1Y').mean().plot(label='Pred_GB')
CNN.sel(time=slice('2015-1-1','2018-12-31')).resample(time='1Y').mean().plot(label='Pred_CNN')
plt.ylim(0, 0.6)
plt.legend()

ax2 = fig.add_subplot(121)
obs.sel(time=slice('1980-1-1','1983-12-31')).resample(time='1Y').mean().plot(label='Obs')
LR.sel(time=slice('1980-1-1','1983-12-31')).resample(time='1Y').mean().plot(label='Pred_LR')
SVR.sel(time=slice('1980-1-1','1983-12-31')).resample(time='1Y').mean().plot(label='Pred_SVR')
GB.sel(time=slice('1980-1-1','1983-12-31')).resample(time='1Y').mean().plot(label='Pred_GB')
CNN.sel(time=slice('1980-1-1','1983-12-31')).resample(time='1Y').mean().plot(label='Pred_CNN')
plt.ylim(0, 0.6)
plt.legend()

plt.savefig('NOAOEU_TS2_Case3.jpeg')
plt.show()
