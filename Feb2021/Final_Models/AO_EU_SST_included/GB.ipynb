# %%
import numpy as np
import pandas as pd
import xarray as xr
import math as mt
from joblib import dump, load
import datetime
from sklearn.model_selection import train_test_split
from random import seed
from random import randint
import statistics
from scipy.stats import stats
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import  RandomizedSearchCV
from time import time
from scipy.stats import uniform
from sklearn.utils.fixes import loguniform
import matplotlib.pyplot as plt
from scipy.stats import randint

# %% [markdown]
# # Load Input Data

# %%
# Load Inputs
# Load X and y values
X = load('X.joblib') 
y= load('y.joblib')

# %% [markdown]
# # Randomaly  Spit train test (20%)

# %%
X_train,X_test,y_train,y_test= train_test_split(X ,y,test_size=0.20, random_state=0)

# %% [markdown]
# # Hyper Parameter tuning on train data 10fold CV and RandomizedSearchCV

# %%
gbReg = GradientBoostingRegressor()


# Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})"
                  .format(results['mean_test_score'][candidate],
                          results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# specify parameters and distributions to sample from
param_dist = {'loss': ['ls','lad'],
              'max_depth': randint(1, 5),
              'n_estimators':randint(100,1000) ,
              'min_samples_leaf':randint(5,25) ,
              'learning_rate': loguniform(1e-3, 1e-1)
             }

# run random search
n_iter_search = 20
random_search = RandomizedSearchCV(gbReg, param_distributions=param_dist,scoring='r2',cv=10,n_iter=n_iter_search)
start = time()
random_search.fit(X_train, y_train)

print("randomSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(random_search.cv_results_['params'])))
report(random_search.cv_results_)
# Out:
# randomSearchCV took 372.43 seconds for 20 candidate parameter settings.
# Model with rank: 1
# Mean validation score: 0.564 (std: 0.060)
# Parameters: {'learning_rate': 0.03086563921830109, 'loss': 'ls', 'max_depth': 3, 'min_samples_leaf': 15, 'n_estimators': 314}
#
# Model with rank: 2
# Mean validation score: 0.561 (std: 0.059)
# Parameters: {'learning_rate': 0.010156654559737405, 'loss': 'ls', 'max_depth': 4, 'min_samples_leaf': 22, 'n_estimators': 718}
#
# Model with rank: 3
# Mean validation score: 0.558 (std: 0.060)
# Parameters: {'learning_rate': 0.011621515682339692, 'loss': 'ls', 'max_depth': 4, 'min_samples_leaf': 15, 'n_estimators': 406}

# %% [markdown]
# # Fit model with selected hyperparameters on train data and test it on test data

# %%
#regLin=GradientBoostingRegressor(n_estimators=500, min_samples_leaf=2, max_depth=4,learning_rate=0.08,random_state=0,loss='lad').fit(X_train, y_train)
#regLin=GradientBoostingRegressor(n_estimators=250, min_samples_leaf=11, max_depth=4,learning_rate=0.05,random_state=0).fit(X_train, y_train)
regLin=GradientBoostingRegressor(n_estimators=500, min_samples_leaf=15, max_depth=4,learning_rate=0.03,random_state=0,loss='ls').fit(X_train, y_train)
acc_svr       =regLin.score(X_test, y_test) 
print("Coefficient of determination of base SVR model on test data is ,",(acc_svr))
yy_test = regLin.predict(X_test)
test_corr = np.corrcoef(yy_test,y_test)[0,1]
plt.title(' SVR corr = %f'%test_corr)
plt.plot(y_test,yy_test,'+')
# Out:
# Coefficient of determination of base SVR model on test data is , 0.6029932468592194

# %% [markdown]
# # Predict all data

# %%
yLR=regLin.predict(X)
y_predLin_ds=xr.Dataset({'yLR': (('time'), yLR)}, coords={'time': y.time})
dump(y_predLin_ds.yLR,'TSdataGB.joblib')
# Out:
# ['TSdataGB.joblib']

# %% [markdown]
# # PLot TS

# %%
plt.figure(figsize=[15,5])
y.resample(time='1Y').mean().plot(label='Obs')
y_predLin_ds.resample(time='1Y').mean().yLR.plot(label='Pred_GB')
dump(y,'TSdataObs.joblib')
plt.ylim(0, 0.6)
plt.legend()

# %% [markdown]
# # Get Categorial Fog days

# %%
ynf=y.where(y<0.040, drop=True)
print(ynf.shape[0])

yint1=y.where(y>=0.04,drop=True)
yintf=yint1.where(yint1<0.48,drop=True)
print(yintf.shape[0])

yWd=y.where(y>=0.48, drop=True)
print(yWd.shape[0])

print((ynf.shape[0]+yintf.shape[0]+yWd.shape[0]))

yLRnf=y_predLin_ds.where(y_predLin_ds.yLR<0.04,drop=True)
print(yLRnf.yLR.shape[0])

yLRint1=y_predLin_ds.where(y_predLin_ds.yLR>=0.04,drop=True)
yLRintf=yLRint1.where(yLRint1<0.48,drop=True)
print(yLRintf.yLR.shape[0])

yLRWd=y_predLin_ds.where(y_predLin_ds.yLR>=0.48,drop=True)
print(yLRWd.yLR.shape[0])

print((yLRnf.yLR.shape[0]+yLRintf.yLR.shape[0]+yLRWd.yLR.shape[0]))
# Out:
# 125
# 1705
# 588
# 2418
# 50
# 1968
# 400
# 2418

# %% [markdown]
# # PLot pie chart of different Categories

# %%
fig = plt.figure(figsize=[10,5])
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pieLabs = ['No Fog', 'Intermediate Fog (1-11)', 'Widespread Fog (>11)']
piedata = [ynf.shape[0],yintf.shape[0],yWd.shape[0]]
ax.pie(piedata, labels = pieLabs,autopct='%1.2f%%')
ax.set_title('Station Observation')
ax1 = fig.add_axes([1,0,1,1])
ax1.axis('equal')
pieLabs = ['No Fog', 'Intermediate Fog (1-11)', 'Widespread Fog (>11)']
piedata = [yLRnf.yLR.shape[0],yLRintf.yLR.shape[0],yLRWd.yLR.shape[0]]
ax1.pie(piedata, labels = pieLabs,autopct='%1.2f%%')
ax1.set_title('GB')
# Out:
# Text(0.5, 1.0, 'GB')

# %%
pie1dataObs = [ynf.shape[0],yintf.shape[0],yWd.shape[0]]
pie1dataLR = [yLRnf.yLR.shape[0],yLRintf.yLR.shape[0],yLRWd.yLR.shape[0]]
dump(pie1dataObs, 'piedataObs.joblib') 
dump(pie1dataLR,'piedataGB.joblib')
# Out:
# ['piedataGB.joblib']
