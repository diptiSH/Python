# %%
import numpy as np
import pandas as pd
import xarray as xr
import math as mt
from joblib import dump, load
import datetime
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.model_selection import  RandomizedSearchCV
from time import time
from scipy.stats import uniform
from sklearn.utils.fixes import loguniform
import matplotlib.pyplot as plt
from scipy.stats import randint

# %%
# Load Inputs
# Load X and y values
X_All = load('X_All.joblib') 
y= load('y_All.joblib')

# %% [markdown]
# #Only near Surface variables

# %%
X=X_All[['t2m', 'ws', 'rh','inv', 'w', 'ushear']]
#X

# %%
X_train,X_test,y_train,y_test= train_test_split(X ,y,test_size=0.20, random_state=0) # train test split random

# %%
# fit model on training data and test on test data
regLin=SVR(C=30,gamma='scale',kernel='rbf',epsilon=0.01).fit(X_train, y_train)
acc_svr       =regLin.score(X_test, y_test) 
print("Coefficient of determination of base SVR model on test data is ,",(acc_svr))
yy_test = regLin.predict(X_test)
test_corr = np.corrcoef(yy_test,y_test)[0,1]
plt.title(' SVR corr = %f'%test_corr)
plt.plot(y_test,yy_test,'+')
# Out:
# Coefficient of determination of base SVR model on test data is , 0.5758917578866855

# %% [markdown]
# #Add  EU Variable

# %%
# eu1

X=X_All[['t2m', 'ws', 'rh','inv', 'w', 'ushear','eu1']]

X_train,X_test,y_train,y_test= train_test_split(X ,y,test_size=0.20, random_state=0) # train test split random

# fit model on training data and test on test data
regLin=SVR(C=30,gamma='scale',kernel='rbf',epsilon=0.01).fit(X_train, y_train)
acc_svr       =regLin.score(X_test, y_test) 
print("Coefficient of determination of base SVR model on test data is ,",(acc_svr))
yy_test = regLin.predict(X_test)
test_corr = np.corrcoef(yy_test,y_test)[0,1]
plt.title(' SVR corr = %f'%test_corr)
plt.plot(y_test,yy_test,'+')
# Out:
# Coefficient of determination of base SVR model on test data is , 0.5694757174925871

# %%
# eu5

X=X_All[['t2m', 'ws', 'rh','inv', 'w', 'ushear','eu5']]

X_train,X_test,y_train,y_test= train_test_split(X ,y,test_size=0.20, random_state=0) # train test split random

# fit model on training data and test on test data
regLin=SVR(C=30,gamma='scale',kernel='rbf',epsilon=0.01).fit(X_train, y_train)
acc_svr       =regLin.score(X_test, y_test) 
print("Coefficient of determination of base SVR model on test data is ,",(acc_svr))
yy_test = regLin.predict(X_test)
test_corr = np.corrcoef(yy_test,y_test)[0,1]
plt.title(' SVR corr = %f'%test_corr)
plt.plot(y_test,yy_test,'+')
# Out:
# Coefficient of determination of base SVR model on test data is , 0.5707179533508979

# %%
# eu7

X=X_All[['t2m', 'ws', 'rh','inv', 'w', 'ushear','eu7']]

X_train,X_test,y_train,y_test= train_test_split(X ,y,test_size=0.20, random_state=0) # train test split random

# fit model on training data and test on test data
regLin=SVR(C=30,gamma='scale',kernel='rbf',epsilon=0.01).fit(X_train, y_train)
acc_svr       =regLin.score(X_test, y_test) 
print("Coefficient of determination of base SVR model on test data is ,",(acc_svr))
yy_test = regLin.predict(X_test)
test_corr = np.corrcoef(yy_test,y_test)[0,1]
plt.title(' SVR corr = %f'%test_corr)
plt.plot(y_test,yy_test,'+')
# Out:
# Coefficient of determination of base SVR model on test data is , 0.5708565060188362

# %%
# eu14

X=X_All[['t2m', 'ws', 'rh','inv', 'w', 'ushear','eu14']]

X_train,X_test,y_train,y_test= train_test_split(X ,y,test_size=0.20, random_state=0) # train test split random

# fit model on training data and test on test data
regLin=SVR(C=30,gamma='scale',kernel='rbf',epsilon=0.01).fit(X_train, y_train)
acc_svr       =regLin.score(X_test, y_test) 
print("Coefficient of determination of base SVR model on test data is ,",(acc_svr))
yy_test = regLin.predict(X_test)
test_corr = np.corrcoef(yy_test,y_test)[0,1]
plt.title(' SVR corr = %f'%test_corr)
plt.plot(y_test,yy_test,'+')
# Out:
# Coefficient of determination of base SVR model on test data is , 0.5733482762125626

# %%
# eu30

X=X_All[['t2m', 'ws', 'rh','inv', 'w', 'ushear','eu30']]

X_train,X_test,y_train,y_test= train_test_split(X ,y,test_size=0.20, random_state=0) # train test split random

# fit model on training data and test on test data
regLin=SVR(C=30,gamma='scale',kernel='rbf',epsilon=0.01).fit(X_train, y_train)
acc_svr       =regLin.score(X_test, y_test) 
print("Coefficient of determination of base SVR model on test data is ,",(acc_svr))
yy_test = regLin.predict(X_test)
test_corr = np.corrcoef(yy_test,y_test)[0,1]
plt.title(' SVR corr = %f'%test_corr)
plt.plot(y_test,yy_test,'+')
# Out:
# Coefficient of determination of base SVR model on test data is , 0.5746555418560994
