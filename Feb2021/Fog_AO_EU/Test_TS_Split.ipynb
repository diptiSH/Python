# %%
import numpy as np
import pandas as pd
import xarray as xr
import math as mt
from joblib import dump, load
import datetime
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Case 1

# %%
obs = load('TS2dataObs_1.joblib') 
LR= load('TS2dataLR_1.joblib')
SVR=load('TS2dataSVR_1.joblib')
GB=load('TS2dataGB_1.joblib')
CNN=load('TS2dataCNN_1.joblib')

fig = plt.figure(figsize=[15,15])
ax = fig.add_subplot(321)
obs.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Obs')
LR.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1)
#plt.legend()

ax2 = fig.add_subplot(322)
obs.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Obs')
LR.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1)
#plt.legend()

ax3 = fig.add_subplot(323)
obs.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Obs')
LR.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1)

ax4 = fig.add_subplot(324)
obs.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Obs')
LR.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1)

ax5 = fig.add_subplot(325)
obs.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Obs')
LR.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_CNN')
plt.ylim(0, 1)

plt.savefig('With_TS2_Case1.jpeg')
plt.legend()
plt.show()

# %%
# Case 2

# %%
obs = load('TS2dataObs_2.joblib') 
LR= load('TS2dataLR_2.joblib')
SVR=load('TS2dataSVR_2.joblib')
GB=load('TS2dataGB_2.joblib')
CNN=load('TS2dataCNN_2.joblib')

fig = plt.figure(figsize=[15,15])
ax = fig.add_subplot(331)
obs.sel(time=slice('2011-1-1','2011-1-31')).plot(label='Obs')
LR.sel(time=slice('2011-1-1','2011-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2011-1-1','2011-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2011-1-1','2011-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2011-1-1','2011-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)
#plt.legend()

ax2 = fig.add_subplot(332)
obs.sel(time=slice('2011-12-1','2012-1-31')).plot(label='Obs')
LR.sel(time=slice('2011-12-1','2012-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2011-12-1','2012-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2011-12-1','2012-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2011-12-1','2012-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)
#plt.legend()

ax3 = fig.add_subplot(333)
obs.sel(time=slice('2012-12-1','2013-1-31')).plot(label='Obs')
LR.sel(time=slice('2012-12-1','2013-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2012-12-1','2013-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2012-12-1','2013-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2012-12-1','2013-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

ax4 = fig.add_subplot(334)
obs.sel(time=slice('2013-12-1','2014-1-31')).plot(label='Obs')
LR.sel(time=slice('2013-12-1','2014-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2013-12-1','2014-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2013-12-1','2014-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2013-12-1','2014-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

ax5 = fig.add_subplot(335)
obs.sel(time=slice('2014-12-1','2015-1-31')).plot(label='Obs')
LR.sel(time=slice('2014-12-1','2015-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2014-12-1','2015-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2014-12-1','2015-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2014-12-1','2015-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

ax6 = fig.add_subplot(336)
obs.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Obs')
LR.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

ax7 = fig.add_subplot(337)
obs.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Obs')
LR.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)


ax8 = fig.add_subplot(338)
obs.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Obs')
LR.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

ax9 = fig.add_subplot(339)
obs.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Obs')
LR.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

plt.savefig('With_TS2_Case2.jpeg')
#plt.savefig('NOAOEU_TS2_Case3.jpeg')
plt.legend()
plt.show()

# %%
# Case 3

# %%
obs = load('TS2dataObs_3.joblib') 
LR= load('TS2dataLR_3.joblib')
SVR=load('TS2dataSVR_3.joblib')
GB=load('TS2dataGB_3.joblib')
CNN=load('TS2dataCNN_3.joblib')

fig = plt.figure(figsize=[18,18])
ax = fig.add_subplot(431)
obs.sel(time=slice('1980-1-1','1980-1-31')).plot(label='Obs')
LR.sel(time=slice('1980-1-1','1980-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('1980-1-1','1980-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('1980-1-1','1980-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('1980-1-1','1980-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)
#plt.legend()

ax2 = fig.add_subplot(432)
obs.sel(time=slice('1980-12-1','1981-1-31')).plot(label='Obs')
LR.sel(time=slice('1980-12-1','1981-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('1980-12-1','1981-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('1980-12-1','1981-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('1980-12-1','1981-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)
#plt.legend()

ax3 = fig.add_subplot(433)
obs.sel(time=slice('1981-12-1','1982-1-31')).plot(label='Obs')
LR.sel(time=slice('1981-12-1','1982-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('1981-12-1','1982-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('1981-12-1','1982-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('1981-12-1','1982-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

ax4 = fig.add_subplot(434)
obs.sel(time=slice('1982-12-1','1983-1-31')).plot(label='Obs')
LR.sel(time=slice('1982-12-1','1983-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('1982-12-1','1983-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('1982-12-1','1983-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('1982-12-1','1983-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)


ax5 = fig.add_subplot(435)
obs.sel(time=slice('1983-12-1','1983-12-31')).plot(label='Obs')
LR.sel(time=slice('1983-12-1','1983-12-31')).plot(label='Pred_LR')
SVR.sel(time=slice('1983-12-1','1983-12-31')).plot(label='Pred_SVR')
GB.sel(time=slice('1983-12-1','1983-12-31')).plot(label='Pred_GB')
CNN.sel(time=slice('1983-12-1','1983-12-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)


ax6 = fig.add_subplot(436)
obs.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Obs')
LR.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2015-1-1','2015-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

ax7 = fig.add_subplot(437)
obs.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Obs')
LR.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2015-12-1','2016-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

ax8 = fig.add_subplot(438)
obs.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Obs')
LR.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2016-12-1','2017-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)


ax9 = fig.add_subplot(439)
obs.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Obs')
LR.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2017-12-1','2018-1-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

ax10 = fig.add_subplot(4,3,10)
obs.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Obs')
LR.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_LR')
SVR.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_SVR')
GB.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_GB')
CNN.sel(time=slice('2018-12-1','2018-12-31')).plot(label='Pred_CNN')
plt.ylim(0, 1.2)

plt.savefig('With_TS2_Case3.jpeg')
#plt.savefig('NOAOEU_TS2_Case3.jpeg')
plt.legend()
plt.show()
