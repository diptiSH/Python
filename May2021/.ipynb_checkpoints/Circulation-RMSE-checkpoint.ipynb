# %%
import xarray as xr
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from math import e
from joblib import dump, load
import xskillscore as xs
from sklearn import preprocessing
import hvplot.xarray 
import cartopy.crs as ccrs
import pyproj

# %%
#era5

# %%
era5Data = xr.open_dataset('../../Data/eraDown/ERA5_2degree_Down/DailyMean/ERA5NH_500_z_daily_NovDecJan.nc')

z=era5Data.z/9.81
z
era5=z[((z.time.dt.month>11) | (z.time.dt.month<2)) & (z.time.dt.year<2020)].sel(time=slice('1980-1-1','2014-12-31'))
era5
# Out:
# <xarray.DataArray 'z' (time: 2170, latitude: 46, longitude: 180)>
# array([[[5162.38  , 5162.38  , 5162.38  , ..., 5162.38  , 5162.38  ,
#          5162.38  ],
#         [5101.8066, 5101.4077, 5101.1196, ..., 5103.491 , 5102.826 ,
#          5102.2725],
#         [5018.848 , 5016.7646, 5015.0356, ..., 5026.5835, 5023.6357,
#          5021.109 ],
#         ...,
#         [5847.613 , 5849.0312, 5849.408 , ..., 5844.1113, 5844.466 ,
#          5846.15  ],
#         [5846.084 , 5847.192 , 5847.3247, ..., 5842.9585, 5843.3354,
#          5844.4214],
#         [5844.887 , 5846.128 , 5846.6157, ..., 5842.2715, 5842.981 ,
#          5844.266 ]],
#
#        [[5126.386 , 5126.386 , 5126.386 , ..., 5126.386 , 5126.386 ,
#          5126.386 ],
#         [5071.664 , 5071.0215, 5070.4673, ..., 5073.8584, 5073.0605,
#          5072.3066],
#         [4987.531 , 4984.871 , 4982.478 , ..., 4996.928 , 4993.4487,
#          4990.368 ],
# ...
#         [5868.292 , 5869.222 , 5869.3555, ..., 5865.0117, 5867.0283,
#          5867.76  ],
#         [5867.7153, 5868.425 , 5869.178 , ..., 5866.2085, 5867.3833,
#          5867.4272],
#         [5869.2446, 5868.6245, 5867.2944, ..., 5866.9395, 5868.336 ,
#          5868.868 ]],
#
#        [[5094.448 , 5094.448 , 5094.448 , ..., 5094.448 , 5094.448 ,
#          5094.448 ],
#         [5071.487 , 5071.376 , 5071.2427, ..., 5071.6865, 5071.62  ,
#          5071.575 ],
#         [5067.741 , 5067.7188, 5067.6523, ..., 5067.431 , 5067.4526,
#          5067.6084],
#         ...,
#         [5854.3506, 5855.0156, 5855.06  , ..., 5852.3115, 5852.1123,
#          5853.021 ],
#         [5855.5254, 5857.099 , 5858.008 , ..., 5852.999 , 5854.1514,
#          5854.373 ],
#         [5857.2983, 5857.6978, 5860.224 , ..., 5856.789 , 5855.6807,
#          5857.587 ]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 1980-01-01T09:00:00 ... 2014-12-31T09:00:00
#   * longitude  (longitude) float32 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#   * latitude   (latitude) float32 90.0 88.0 86.0 84.0 82.0 ... 6.0 4.0 2.0 0.0

# %%
era5['time'] = EC_Earth3.time
era5.time
# Out:
# <xarray.DataArray 'time' (time: 2170)>
# array(['1980-01-01T12:00:00.000000000', '1980-01-02T12:00:00.000000000',
#        '1980-01-03T12:00:00.000000000', ..., '2014-12-29T12:00:00.000000000',
#        '2014-12-30T12:00:00.000000000', '2014-12-31T12:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01T12:00:00 ... 2014-12-31T12:00:00
#     plev     float64 5e+04
# Attributes:
#     standard_name:  time
#     long_name:      time
#     bounds:         time_bnds
#     axis:           T

# %%
#EC-Earth3

# %%
zLevData = xr.open_dataset('../../Data/CMIP6/EC-Earth3/processed/Regrid_zg_day_EC-Earth3_historical_r1i1p1f1_gr_18500101-20141231.nc')
zLevData
z=zLevData.sel(plev=50000,method='nearest').zg
EC_Earth3=z[((z.time.dt.month>11) | (z.time.dt.month<2)) & (z.time.dt.year<2020)].sel(time=slice('1980-1-1','2014-12-31'))
EC_Earth3
# Out:
# <xarray.DataArray 'zg' (time: 2170, latitude: 46, longitude: 180)>
# [17967600 values with dtype=float32]
# Coordinates:
#   * time       (time) datetime64[ns] 1980-01-01T12:00:00 ... 2014-12-31T12:00:00
#   * longitude  (longitude) float32 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#   * latitude   (latitude) float32 90.0 88.0 86.0 84.0 82.0 ... 6.0 4.0 2.0 0.0
#     plev       float64 5e+04
# Attributes:
#     standard_name:  geopotential_height
#     long_name:      Geopotential Height
#     units:          m
#     comment:        Geopotential is the sum of the specific gravitational pot...
#     cell_methods:   time: mean
#     cell_measures:  area: areacella
#     history:        2019-09-25T21:23:04Z altered by CMOR: Reordered dimension...

# %%
r = xs.pearson_r(era5, EC_Earth3, dim='time')
r
p = xs.pearson_r_p_value(era5, EC_Earth3, dim='time')
#p
r
# Out:
# <xarray.DataArray (latitude: 46, longitude: 180)>
# array([[-0.02417113, -0.02417113, -0.02417113, ..., -0.02417113,
#         -0.02417113, -0.02417113],
#        [-0.01111495, -0.01063567, -0.01016284, ..., -0.01260401,
#         -0.01209699, -0.01159969],
#        [ 0.01617952,  0.0166591 ,  0.01712692, ...,  0.01457451,
#          0.01514572,  0.01567833],
#        ...,
#        [ 0.1479817 ,  0.1424958 ,  0.13954055, ...,  0.16711167,
#          0.16045487,  0.1544076 ],
#        [ 0.14005996,  0.13619493,  0.13354918, ...,  0.15375364,
#          0.14918576,  0.14395489],
#        [ 0.13705008,  0.13372663,  0.12921433, ...,  0.14715616,
#          0.14354178,  0.14135645]], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#   * latitude   (latitude) float32 90.0 88.0 86.0 84.0 82.0 ... 6.0 4.0 2.0 0.0
#     plev       float64 5e+04

# %%
r.hvplot.image(x='longitude', y='latitude')
# Out:
# :Image   [longitude,latitude]   (value)

# %%
r.hvplot.contourf(
    'xc', 'yc', crs=ccrs.PlateCarree(), projection=ccrs.PlateCarree(),
    ylim=(0, 90), frame_width=800, cmap='viridis', levels=10,
    coastline=True
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/hvplot/util.py in process_crs(crs)
#     180         import cartopy.crs as ccrs
# --> 181         import geoviews as gv # noqa
#     182         import pyproj
#
# ModuleNotFoundError: No module named 'geoviews'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-a6aa536bb9a5> in <module>
# ----> 1 r.hvplot.contourf(
#       2     'xc', 'yc', crs=ccrs.PlateCarree(), projection=ccrs.PlateCarree(),
#       3     ylim=(0, 90), frame_width=800, cmap='viridis', levels=10,
#       4     coastline=True
#       5 )
#
# ~/anaconda3/lib/python3.8/site-packages/hvplot/plotting/core.py in contourf(self, x, y, z, colorbar, **kwds)
#     719             The HoloViews representation of the plot.
#     720         """
# --> 721         return self(x, y, z=z, kind='contourf', colorbar=colorbar, **kwds)
#
# ~/anaconda3/lib/python3.8/site-packages/hvplot/plotting/core.py in __call__(self, x, y, kind, **kwds)
#      77                 return pn.panel(plot, **panel_dict)
#      78
# ---> 79         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      80
#      81     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# ~/anaconda3/lib/python3.8/site-packages/hvplot/plotting/core.py in _get_converter(self, x, y, kind, **kwds)
#      84         y = y or params.pop('y', None)
#      85         kind = kind or params.pop('kind', None)
# ---> 86         return HoloViewsConverter(
#      87             self._data, x, y, kind=kind, **params
#      88         )
#
# ~/anaconda3/lib/python3.8/site-packages/hvplot/converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, figsize, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, **kwds)
#     328         self.dynamic = dynamic
#     329         self.geo = any([geo, crs, global_extent, projection, project, coastline])
# --> 330         self.crs = self._process_crs(data, crs) if self.geo else None
#     331         self.project = project
#     332         self.coastline = coastline
#
# ~/anaconda3/lib/python3.8/site-packages/hvplot/converter.py in _process_crs(self, data, crs)
#     554         _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     555         try:
# --> 556             return process_crs(_crs)
#     557         except ValueError:
#     558             # only raise error if crs was specified in kwargs
#
# ~/anaconda3/lib/python3.8/site-packages/hvplot/util.py in process_crs(crs)
#     182         import pyproj
#     183     except:
# --> 184         raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     185
#     186     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews and cartopy.
